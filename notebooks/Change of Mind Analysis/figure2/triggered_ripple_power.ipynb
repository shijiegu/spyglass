# %% [markdown]
# ### Change of mind triggered ripple power

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import os
import numpy as np
import pandas as pd
import xarray as xr

# ignore datajoint+jupyter async warnings
import warnings
warnings.simplefilter('ignore', category=DeprecationWarning)
warnings.simplefilter('ignore', category=ResourceWarning)
warnings.simplefilter('ignore', category=UserWarning)

import matplotlib.pyplot as plt

# %%
from spyglass.utils.nwb_helper_fn import get_nwb_copy_filename
from spyglass.common import IntervalList
from spyglass.linearization.v0.main import IntervalLinearizedPosition
from spyglass.shijiegu.decodeHelpers import session2position_name

from spyglass.shijiegu.ripple_detection import loadRippleLFP_OneChannelPerElectrode
from spyglass.shijiegu.Analysis_SGU import ChangeofMind
from spyglass.shijiegu.load import load_session_name, load_position
from spyglass.shijiegu.helpers import mergeIntervals,interpolate_to_new_time
from spyglass.shijiegu.ripple_add_replay import select_subset_helper_pd

# %%
def return_triggered_ripples(df, trialIDs, pos_info, time_type, session_mean, session_sd):
    filtered_lfps_subset_all = []

    for trialID in trialIDs:
        if time_type == "com": #change of mind
            t = df.loc[trialID].initial_time
        elif "reward" in time_type: #change of mind
            t = df.loc[trialID].timestamp_O
            
        t0, t1 = (t - 1, t + 3)
        t_axis = np.linspace(t0, t1, 4000)
        t_ind = np.logical_and(filtered_lfps_t_maze >= t0, filtered_lfps_t_maze <= t1)
        filtered_lfps_t_subset = filtered_lfps_t_maze[t_ind]
        filtered_lfps_subset = (np.mean(filtered_lfps_raw_maze[t_ind,:] ** 2, axis = 1) - session_mean) / session_sd

        pos_info_subset = select_subset_helper_pd(pos_info, (t0, t1+0.01))
        pos_info_subset = pos_info_subset.iloc[:len(filtered_lfps_subset)]
        assert len(pos_info_subset) == len(filtered_lfps_subset)
        low_speed_ind = np.array(pos_info_subset.head_speed) <= 4
        filtered_lfps_t_subset = filtered_lfps_t_subset[low_speed_ind]
        filtered_lfps_subset = filtered_lfps_subset[low_speed_ind]
        
        bins = np.digitize(filtered_lfps_t_subset, t_axis) - 1
        filtered_lfps_binned = np.zeros_like(t_axis)
        filtered_lfps_binned_count = np.zeros_like(t_axis)
        for ind in range(len(bins)):
            target_ind = bins[ind]
            filtered_lfps_binned[target_ind] += filtered_lfps_subset[ind]
            filtered_lfps_binned_count[target_ind] += 1
        filtered_lfps_binned = filtered_lfps_binned/filtered_lfps_binned_count
    
        filtered_lfps_subset_all.append(filtered_lfps_binned)
    filtered_lfps_subset_all = np.array(filtered_lfps_subset_all)
    
    t_axis = t_axis - t

    return filtered_lfps_subset_all, t_axis

# %%
nwb_file_name = "eliot20221021.nwb"

# %%
nwb_copy_file_name = get_nwb_copy_filename(nwb_file_name)
animal = nwb_file_name[:5]

# %%
session_interval, sleep_interval = load_session_name(nwb_copy_file_name)
print(session_interval)
# Out:
# ['02_Seq2Session1', '04_Seq2Session2', '06_Seq2Session3', '08_Seq2Session4']

# %%
#df[df.rewardNum == 1]

# %%
com_all = []
reward_all = []

for session_name in session_interval:

    position_valid_times = (IntervalList & {'nwb_file_name': nwb_copy_file_name,
                                            'interval_list_name': session_name}).fetch1('valid_times')
    epoch_pos_name = session2position_name(nwb_copy_file_name, session_name)

    q = {"proportion": 0.1,
     "delta_t_minus":5, "delta_t_plus":5,
     "max_flag":1}

    q["nwb_file_name"] = nwb_copy_file_name
    q["epoch"] = session_name[:2]
    df = ChangeofMind().fetch1_dataframe(q)         # trials with long theta

    df_com = df[df.change_of_mind]
    df_nonreward = df[df.rewardNum == 1]

    #filtered_lfps, filtered_lfps_t, CA1TetrodeInd, CCTetrodeInd = loadRippleLFP_OneChannelPerElectrode(
    #    nwb_copy_file_name,session_name,position_valid_times,'artifact removed filtered data',1)
    

    (filtered_lfps_raw, filtered_lfps_t,
     _2, _3) = loadRippleLFP_OneChannelPerElectrode(
         nwb_copy_file_name,
         session_name,position_valid_times,'filtered data',1)

    position_info = load_position(nwb_copy_file_name,epoch_pos_name)
    position_info_upsample = interpolate_to_new_time(position_info, filtered_lfps_t)

    t0, t1 = (df.loc[1].timestamp_O, df.loc[80].timestamp_O)

    t_ind = np.logical_and(filtered_lfps_t >= t0, filtered_lfps_t <= t1)

    # get session threshold
    filtered_lfps_raw_maze = filtered_lfps_raw[t_ind]
    filtered_lfps_t_maze = filtered_lfps_t[t_ind]
    session_mean = np.mean(np.mean(filtered_lfps_raw_maze ** 2, axis = 1))
    session_sd = np.std(np.mean(filtered_lfps_raw_maze ** 2, axis = 1))

    lfp_com, t_axis_com = return_triggered_ripples(df, df_com.index[df_com.index < 80], position_info_upsample,
                                                            "com", session_mean, session_sd)

    lfp_reward, t_axis_reward = return_triggered_ripples(df, df_nonreward.index[df_nonreward.index < 80],position_info_upsample,
                                                            "reward", session_mean, session_sd)

    com_all.append(lfp_com)
    reward_all.append(lfp_reward)

com_all = np.vstack(com_all)
reward_all = np.vstack(reward_all)
# Out:
# [2025-11-10 16:23:16,681][WARNING]: Skipped checksum for file with hash: 145544ce-9b16-2ab9-f0ac-df5a62adb5f5, and path: /stelmo/nwb/analysis/eliot20221021/eliot20221021_ZXS05TLCX7.nwb
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[230], line 16
#      14 q["nwb_file_name"] = nwb_copy_file_name
#      15 q["epoch"] = session_name[:2]
# ---> 16 df = ChangeofMind().fetch1_dataframe(q)         # trials with long theta
#      18 df_com = df[df.change_of_mind]
#      19 df_nonreward = df[df.rewardNum == 1]
#
# File ~/Documents/spyglass/src/spyglass/shijiegu/Analysis_SGU.py:442, in ChangeofMind.fetch1_dataframe(self, key)
#     439 analysis_file_abs_path = (AnalysisNwbfile() & {
#     440     "analysis_file_name":analysis_nwb_file_name}).fetch1('analysis_file_abs_path')
#     441 with pynwb.NWBHDF5IO(analysis_file_abs_path, 'r',load_namespaces=True) as io:
# --> 442     nwb_file = io.read()
#     443     df = nwb_file.scratch["pandas_table"].to_dataframe()
#     444 return df
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/utils.py:577, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     575 def func_call(*args, **kwargs):
#     576     pargs = _check_args(args, kwargs)
# --> 577     return func(args[0], **pargs)
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/__init__.py:458, in NWBHDF5IO.read(self, **kwargs)
#     455         raise TypeError("NWB version %s not supported. PyNWB supports NWB files version 2 and above." %
#     456                         str(file_version_str))
#     457 # read the file
# --> 458 file = super().read(**kwargs)
#     459 return file
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/backends/hdf5/h5tools.py:500, in HDF5IO.read(self, **kwargs)
#     497     raise UnsupportedOperation("Cannot read from file %s in mode '%s'. Please use mode 'r', 'r+', or 'a'."
#     498                                % (self.source, self.__mode))
#     499 try:
# --> 500     return super().read(**kwargs)
#     501 except UnsupportedOperation as e:
#     502     if str(e) == 'Cannot build data. There are no values.':  # pragma: no cover
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/utils.py:577, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     575 def func_call(*args, **kwargs):
#     576     pargs = _check_args(args, kwargs)
# --> 577     return func(args[0], **pargs)
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/backends/io.py:60, in HDMFIO.read(self, **kwargs)
#      57 if all(len(v) == 0 for v in f_builder.values()):
#      58     # TODO also check that the keys are appropriate. print a better error message
#      59     raise UnsupportedOperation('Cannot build data. There are no values.')
# ---> 60 container = self.__manager.construct(f_builder)
#      61 container.read_io = self
#      62 if self.herd_path is not None:
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/utils.py:577, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     575 def func_call(*args, **kwargs):
#     576     pargs = _check_args(args, kwargs)
# --> 577     return func(args[0], **pargs)
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/build/manager.py:286, in BuildManager.construct(self, **kwargs)
#     282     result = self.__type_map.construct(builder, self, parent)
#     283 else:
#     284     # we are at the top of the hierarchy,
#     285     # so it must be time to resolve parents
# --> 286     result = self.__type_map.construct(builder, self, None)
#     287     self.__resolve_parents(result)
#     288 self.prebuilt(result, builder)
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/utils.py:577, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     575 def func_call(*args, **kwargs):
#     576     pargs = _check_args(args, kwargs)
# --> 577     return func(args[0], **pargs)
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/build/manager.py:813, in TypeMap.construct(self, **kwargs)
#     811     raise ValueError('No ObjectMapper found for builder of type %s' % dt)
#     812 else:
# --> 813     return obj_mapper.construct(builder, build_manager, parent)
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/utils.py:577, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     575 def func_call(*args, **kwargs):
#     576     pargs = _check_args(args, kwargs)
# --> 577     return func(args[0], **pargs)
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/build/objectmapper.py:1319, in ObjectMapper.construct(self, **kwargs)
#    1317 cls = manager.get_cls(builder)
#    1318 # gather all subspecs
# -> 1319 subspecs = self.__get_subspec_values(builder, self.spec, manager)
#    1320 # get the constructor argument that each specification corresponds to
#    1321 const_args = dict()
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/build/objectmapper.py:1248, in ObjectMapper.__get_subspec_values(self, builder, spec, manager)
#    1246                 ret[subspec] = self.__flatten(sub_builder, subspec, manager)
#    1247     # now process groups and datasets
# -> 1248     self.__get_sub_builders(groups, spec.groups, manager, ret)
#    1249     self.__get_sub_builders(datasets, spec.datasets, manager, ret)
#    1250 elif isinstance(spec, DatasetSpec):
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/build/objectmapper.py:1299, in ObjectMapper.__get_sub_builders(self, sub_builders, subspecs, manager, ret)
#    1296     continue
#    1297 if dt is None:
#    1298     # recurse
# -> 1299     ret.update(self.__get_subspec_values(sub_builder, subspec, manager))
#    1300 else:
#    1301     ret[subspec] = manager.construct(sub_builder)
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/build/objectmapper.py:1248, in ObjectMapper.__get_subspec_values(self, builder, spec, manager)
#    1246                 ret[subspec] = self.__flatten(sub_builder, subspec, manager)
#    1247     # now process groups and datasets
# -> 1248     self.__get_sub_builders(groups, spec.groups, manager, ret)
#    1249     self.__get_sub_builders(datasets, spec.datasets, manager, ret)
#    1250 elif isinstance(spec, DatasetSpec):
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/build/objectmapper.py:1299, in ObjectMapper.__get_sub_builders(self, sub_builders, subspecs, manager, ret)
#    1296     continue
#    1297 if dt is None:
#    1298     # recurse
# -> 1299     ret.update(self.__get_subspec_values(sub_builder, subspec, manager))
#    1300 else:
#    1301     ret[subspec] = manager.construct(sub_builder)
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/build/objectmapper.py:1248, in ObjectMapper.__get_subspec_values(self, builder, spec, manager)
#    1246                 ret[subspec] = self.__flatten(sub_builder, subspec, manager)
#    1247     # now process groups and datasets
# -> 1248     self.__get_sub_builders(groups, spec.groups, manager, ret)
#    1249     self.__get_sub_builders(datasets, spec.datasets, manager, ret)
#    1250 elif isinstance(spec, DatasetSpec):
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/build/objectmapper.py:1291, in ObjectMapper.__get_sub_builders(self, sub_builders, subspecs, manager, ret)
#    1289     sub_builder = builder_dt.get(dt)
#    1290     if sub_builder is not None:
# -> 1291         sub_builder = self.__flatten(sub_builder, subspec, manager)
#    1292         ret[subspec] = sub_builder
#    1293 else:
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/build/objectmapper.py:1304, in ObjectMapper.__flatten(self, sub_builder, subspec, manager)
#    1303 def __flatten(self, sub_builder, subspec, manager):
# -> 1304     tmp = [manager.construct(b) for b in sub_builder]
#    1305     if len(tmp) == 1 and not subspec.is_many():
#    1306         tmp = tmp[0]
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/build/objectmapper.py:1304, in <listcomp>(.0)
#    1303 def __flatten(self, sub_builder, subspec, manager):
# -> 1304     tmp = [manager.construct(b) for b in sub_builder]
#    1305     if len(tmp) == 1 and not subspec.is_many():
#    1306         tmp = tmp[0]
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/utils.py:577, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     575 def func_call(*args, **kwargs):
#     576     pargs = _check_args(args, kwargs)
# --> 577     return func(args[0], **pargs)
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/build/manager.py:282, in BuildManager.construct(self, **kwargs)
#     280 if parent_builder is not None:
#     281     parent = self._get_proxy_builder(parent_builder)
# --> 282     result = self.__type_map.construct(builder, self, parent)
#     283 else:
#     284     # we are at the top of the hierarchy,
#     285     # so it must be time to resolve parents
#     286     result = self.__type_map.construct(builder, self, None)
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/utils.py:577, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     575 def func_call(*args, **kwargs):
#     576     pargs = _check_args(args, kwargs)
# --> 577     return func(args[0], **pargs)
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/build/manager.py:813, in TypeMap.construct(self, **kwargs)
#     811     raise ValueError('No ObjectMapper found for builder of type %s' % dt)
#     812 else:
# --> 813     return obj_mapper.construct(builder, build_manager, parent)
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/utils.py:577, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     575 def func_call(*args, **kwargs):
#     576     pargs = _check_args(args, kwargs)
# --> 577     return func(args[0], **pargs)
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/build/objectmapper.py:1349, in ObjectMapper.construct(self, **kwargs)
#    1347     kwargs[argname] = val
#    1348 try:
# -> 1349     obj = self.__new_container__(cls, builder.source, parent, builder.attributes.get(self.__spec.id_key()),
#    1350                                  **kwargs)
#    1351 except Exception as ex:
#    1352     msg = 'Could not construct %s object due to: %s' % (cls.__name__, ex)
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/build/objectmapper.py:1362, in ObjectMapper.__new_container__(self, cls, container_source, parent, object_id, **kwargs)
#    1358 obj = cls.__new__(cls, container_source=container_source, parent=parent, object_id=object_id,
#    1359                   in_construct_mode=True)
#    1360 # obj has been created and is in construction mode, indicating that the object is being constructed by
#    1361 # the automatic construct process during read, rather than by the user
# -> 1362 obj.__init__(**kwargs)
#    1363 obj._in_construct_mode = False  # reset to False to indicate that the construction of the object is complete
#    1364 return obj
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/utils.py:577, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     575 def func_call(*args, **kwargs):
#     576     pargs = _check_args(args, kwargs)
# --> 577     return func(args[0], **pargs)
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/build/classgenerator.py:357, in CustomClassGenerator.set_init.<locals>.__init__(self, **kwargs)
#     353 # TODO should super() be used above instead of base?
#     354
#     355 # set the fields that are new to this class (not inherited)
#     356 for f, arg_val in new_kwargs.items():
# --> 357     setattr(self, f, arg_val)
#     359 # set the fields that have fixed values using the fields dict directly
#     360 # because the setters do not allow setting the value
#     361 for f in fixed_value_attrs_to_set:
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/container.py:91, in AbstractContainer._setter.<locals>.setter(self, val)
#      87     msg = "can't set attribute '%s' -- already set" % name
#      88     raise AttributeError(msg)
#      89 self.fields[name] = self._field_config(arg_name=name,
#      90                                        val=val,
# ---> 91                                        type_map=self._get_type_map())
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/core.py:51, in NWBMixin._get_type_map(self)
#      50 def _get_type_map(self):
# ---> 51     return get_type_map()
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/utils.py:581, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     579 def func_call(*args, **kwargs):
#     580     pargs = _check_args(args, kwargs)
# --> 581     return func(**pargs)
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/__init__.py:119, in get_type_map(**kwargs)
#     117 type_map = None
#     118 if extensions is None:
# --> 119     type_map = deepcopy(__TYPE_MAP)
#     120 else:
#     121     if isinstance(extensions, TypeMap):
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/copy.py:153, in deepcopy(x, memo, _nil)
#     151 copier = getattr(x, "__deepcopy__", None)
#     152 if copier is not None:
# --> 153     y = copier(memo)
#     154 else:
#     155     reductor = dispatch_table.get(cls)
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/build/manager.py:441, in TypeMap.__deepcopy__(self, memo)
#     438 def __deepcopy__(self, memo):
#     439     # XXX: From @nicain: All of a sudden legacy tests started
#     440     #      needing this argument in deepcopy. Doesn't hurt anything, though.
# --> 441     return self.__copy__()
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/build/manager.py:435, in TypeMap.__copy__(self)
#     433 def __copy__(self):
#     434     ret = TypeMap(copy(self.__ns_catalog), self.__default_mapper_cls, self.type_config)
# --> 435     ret.merge(self)
#     436     return ret
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/build/manager.py:461, in TypeMap.merge(self, type_map, ns_catalog)
#     459     for data_type in type_map.__container_types[namespace]:
#     460         container_cls = type_map.__container_types[namespace][data_type]
# --> 461         self.register_container_type(namespace, data_type, container_cls)
#     462 for container_cls in type_map.__mapper_cls:
#     463     self.register_map(container_cls, type_map.__mapper_cls[container_cls])
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/utils.py:577, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     575 def func_call(*args, **kwargs):
#     576     pargs = _check_args(args, kwargs)
# --> 577     return func(args[0], **pargs)
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/build/manager.py:748, in TypeMap.register_container_type(self, **kwargs)
#     746 ''' Map a container class to a data_type '''
#     747 namespace, data_type, container_cls = getargs('namespace', 'data_type', 'container_cls', kwargs)
# --> 748 spec = self.__ns_catalog.get_spec(namespace, data_type)  # make sure the spec exists
#     749 self.__container_types.setdefault(namespace, dict())
#     750 self.__container_types[namespace][data_type] = container_cls
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/utils.py:577, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     575 def func_call(*args, **kwargs):
#     576     pargs = _check_args(args, kwargs)
# --> 577     return func(args[0], **pargs)
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/spec/namespace.py:316, in NamespaceCatalog.get_spec(self, **kwargs)
#     314 if namespace not in self.__namespaces:
#     315     raise KeyError("'%s' not a namespace" % namespace)
# --> 316 return self.__namespaces[namespace].get_spec(data_type)
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/utils.py:577, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     575 def func_call(*args, **kwargs):
#     576     pargs = _check_args(args, kwargs)
# --> 577     return func(args[0], **pargs)
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/spec/namespace.py:148, in SpecNamespace.get_spec(self, **kwargs)
#     146 """Get the Spec object for the given data type"""
#     147 data_type = getargs('data_type', kwargs)
# --> 148 spec = self.__catalog.get_spec(data_type)
#     149 if spec is None:
#     150     raise ValueError("No specification for '%s' in namespace '%s'" % (data_type, self.name))
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/utils.py:576, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     575 def func_call(*args, **kwargs):
# --> 576     pargs = _check_args(args, kwargs)
#     577     return func(args[0], **pargs)
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/utils.py:548, in docval.<locals>.dec.<locals>._check_args(args, kwargs)
#     544 """Parse and check arguments to decorated function. Raise warnings and errors as appropriate."""
#     545 # this function was separated from func_call() in order to make stepping through lines of code using pdb
#     546 # easier
# --> 548 parsed = __parse_args(
#     549     loc_val,
#     550     args[1:] if is_method else args,
#     551     kwargs,
#     552     enforce_type=enforce_type,
#     553     enforce_shape=enforce_shape,
#     554     allow_extra=allow_extra,
#     555     allow_positional=allow_positional
#     556 )
#     558 parse_warnings = parsed.get('future_warnings')
#     559 if parse_warnings:
#
# File ~/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/utils.py:276, in __parse_args(validator, args, kwargs, enforce_type, enforce_shape, allow_extra, allow_positional)
#     273     argval = args[argsi]
#     274     argval_set = True
# --> 276 if not argval_set:
#     277     type_errors.append("missing argument '%s'" % argname)
#     278 else:
#
# KeyboardInterrupt:

# %%
fig, axes = plt.subplots(1,2,figsize = (8, 2),sharey = True)

ax = axes[0]
for lfp in com_all:
    ax.plot(t_axis_com, lfp, alpha = 0.5)
mean = np.mean(com_all,axis = 0)
#std = np.std(com_all,axis = 0)

#ax.plot(t_axis_com, mean, color = 'k', linewidth = 2, label = "mean trace")
#ax.fill_between(t_axis_com, mean - std, mean + std, color = 'magenta', alpha = 0.5)
ax.set_title("Change of mind trials")
ax.set_xlabel("time since change of mind stopping (second)")
ax.set_ylabel("z scored ripple power")
#ax.legend()

ax1 = axes[1]
for lfp in reward_all:
    ax1.plot(t_axis_reward, lfp, alpha = 0.5)
mean = np.mean(reward_all,axis = 0)
#std = np.std(reward_all,axis = 0)

#ax1.plot(t_axis_reward, mean, color = 'k', linewidth = 2, label = "mean trace")
#ax1.fill_between(t_axis_reward, mean - std, mean + std, color = 'magenta', alpha = 0.5)
ax1.set_title("Nonrewarded trials")
ax1.set_xlabel("time since well poke (second)")
ax1.set_ylabel("z scored ripple power")
ax1.tick_params(labelleft=True)
ax1.set_ylim([-1,8])
plt.savefig(f'triggered_ripple_power_{animal}.pdf',dpi=300,bbox_inches='tight')
