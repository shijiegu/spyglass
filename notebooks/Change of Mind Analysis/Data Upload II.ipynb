# %% [markdown]
# ## Data Upload II

# %%
from spyglass.common.common_dandi import DandiPath
# Out:
# [2026-05-24 19:15:22,351][INFO]: DataJoint 0.14.4 connected to shijiegu-alt@lmf-db.cin.ucsf.edu:3306

# %%
paper_key = {"paper_id": "Gu2026"}

# %%
DandiPath().write_mysqldump(paper_key)
# Out:
# [19:15:43][INFO] Spyglass: Export script written to /stelmo/nwb/export/Gu2026/_ExportSQL_Gu2026_dandi.sh
