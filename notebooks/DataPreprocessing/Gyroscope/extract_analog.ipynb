# %% [markdown]
# ## extract analog

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import pynwb
import pyarrow as pa
import pyarrow.parquet as pq
import pandas as pd

# %%
from rec_to_binaries import extract_trodes_rec_file

# %%
data_dir = '/stelmo/shijie/recording_pilot/'
animal = 'molly'
out_dir = '/stelmo/shijie/recording_pilot/preprocessing' #preprocessing folder

# %%
extract_trodes_rec_file(data_dir,
                        animal,
                        out_dir=out_dir,
                        dates=['20220418'],
                        extract_analog=True,
                        extract_spikes=False,
                        extract_lfps=False,
                        extract_dio=False,
                        extract_time=False,
                        extract_mda=False,
                        adjust_timestamps_for_mcu_lag=True,
                        make_mountain_dir=False,
                        make_pos_dir=False,
                        overwrite=False,
                        stop_error=False,
                        use_folder_date=False,
                        parallel_instances=1,
                        use_day_config=True,  
                        trodes_version = (1,9,1),
                        )
# Out:
# File (/stelmo/shijie/recording_pilot/molly/preprocessing/20220415/20220415_molly_01_SeqSleep1.DIO/20220415_molly_01_SeqSleep1.dio.log) does not match file parser (TrodesDIOExtractedFileNameParser). Skipping.
# File (/stelmo/shijie/recording_pilot/molly/preprocessing/20220415/20220415_molly_02_SeqSession1.DIO/20220415_molly_02_SeqSession1.dio.log) does not match file parser (TrodesDIOExtractedFileNameParser). Skipping.
# File (/stelmo/shijie/recording_pilot/molly/preprocessing/20220415/20220415_molly_03_SeqSleep2.DIO/20220415_molly_03_SeqSleep2.dio.log) does not match file parser (TrodesDIOExtractedFileNameParser). Skipping.
# File (/stelmo/shijie/recording_pilot/molly/preprocessing/20220415/20220415_molly_04_Seq2Session1.DIO/20220415_molly_04_Seq2Session1.dio.log) does not match file parser (TrodesDIOExtractedFileNameParser). Skipping.
# ...

# %%
# %debug
# Out:
# > /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/rec_to_binaries/trodes_data.py(244)__init__()
#     242         self.raw_trodescomments_files = {}
#     243
# --> 244         assert 1==0
#     245
#     246         # Loads and caches all raw data files that exist
# ipdb>  raw_day_paths
# {'20220418': '/stelmo/shijie/recording_pilot/molly/raw/20220418', '20220420': '/stelmo/shijie/recording_pilot/molly/raw/20220420', '20220415': '/stelmo/shijie/recording_pilot/molly/raw/20220415', '20220416': '/stelmo/shijie/recording_pilot/molly/raw/20220416', '20220419': '/stelmo/shijie/recording_pilot/molly/raw/20220419', '20220417': '/stelmo/shijie/recording_pilot/molly/raw/20220417'}
# ipdb>  raw_day_paths.items()
# ...
