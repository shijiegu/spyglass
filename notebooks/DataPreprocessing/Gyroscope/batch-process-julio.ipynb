# %% [markdown]
# ## Batch-process Gyroscope: Julio

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import pynwb
import pyarrow as pa
import pyarrow.parquet as pq
import pandas as pd

from spyglass.shijiegu.gyroscope import (
    batch_process_animal,
    gyroscope_data_day,
    extract_gyro_data_in_interval, extract_position_data_in_interval,
    prepare_data_for_tracking,run_trodes_tracking)

from spyglass.utils.nwb_helper_fn import get_nwb_copy_filename
from spyglass.shijiegu.decodeHelpers import runSessionNames
from spyglass.common.common_position import IntervalPositionInfo

from spyglass.shijiegu.Analysis_SGU import ChangeofMindRemoteTheta, ChangeofMindTheta
from spyglass.shijiegu.helpers import mergeIntervals,interpolate_to_new_time

# %%
list_of_days_animals = {}

# %%
animal = 'julio'
list_of_days_animals[animal] = ['20230731','20230801','20230802','20230803','20230804',
                 '20230805','20230806','20230807','20230808','20230809','20230810','20230811']

# %%
animal = 'klein'
list_of_days_animals[animal] = ['20231101','20231102','20231103','20231104','20231105',#
                 '20231106','20231107','20231108','20231109','20231111']

# %%
animal = 'molly'
list_of_days_animals[animal] = ['20220418','20220419','20220420']#['20220416','20220417','20220418','20220419','20220420']

# 20220418, 08_Seq2Session4 trial 17 have trouble aligning time

# %%
animal = 'molly'
output_folder = '/stelmo/shijie/gyro/'
parent_folder = f"/stelmo/shijie/recording_pilot/{animal}/preprocessing/"
success = 0
success = batch_process_animal(animal, list_of_days_animals[animal], output_folder, parent_folder)
# Out:
# [2025-12-17 16:00:26,137][WARNING]: Skipped checksum for file with hash: efe0da3c-2a85-7dcc-1866-f972e9d2298a, and path: /stelmo/nwb/raw/molly20220418_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: efe0da3c-2a85-7dcc-1866-f972e9d2298a, and path: /stelmo/nwb/raw/molly20220418_.nwb
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.5.1 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'core' version 2.4.0 because version 2.7.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.2.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'ndx-franklab-novela' version 0.1.0 because version 0.2.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_0' has data shape (97358, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_1' has data shape (47968, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_10' has data shape (121927, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_2' has data shape (142051, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_3' has data shape (32307, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_4' has data shape (112677, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_5' has data shape (47423, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_6' has data shape (156400, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_7' has data shape (44675, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_8' has data shape (147505, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_9' has data shape (45567, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# *nwb_file_name *epoch    epoch_name     position_inter
# +------------+ +-------+ +------------+ +------------+
# molly20220418_ 1         01_Seq2Sleep1  pos 0 valid ti
# molly20220418_ 2         02_Seq2Session pos 1 valid ti
# molly20220418_ 3         03_Seq2Sleep2  pos 2 valid ti
# molly20220418_ 4         04_Seq2Session pos 3 valid ti
# molly20220418_ 5         05_Seq2Sleep3  pos 4 valid ti
# molly20220418_ 6         06_Seq2Session pos 5 valid ti
# molly20220418_ 7         07_Seq2Sleep4  pos 6 valid ti
# molly20220418_ 8         08_Seq2Session pos 7 valid ti
# molly20220418_ 9         09_Seq2Sleep5  pos 8 valid ti
# molly20220418_ 10        10_Seq2Session pos 9 valid ti
# molly20220418_ 11        11_Seq2Sleep6  pos 10 valid t
#  (Total: 11)
#
# loading gyroscope data for session: 02_Seq2Session1
# GyroY
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/rec_to_binaries/read_binaries.py:73: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   return np.dtype(typearr)
# AccelZ
# GyroX
# AccelY
# GyroZ
# AccelX
# timestamps
# analogio
# loading gyroscope data for session: 04_Seq2Session2
# AccelZ
# timestamps
# GyroZ
# GyroY
# AccelX
# analogio
# AccelY
# GyroX
# loading gyroscope data for session: 06_Seq2Session3
# GyroZ
# timestamps
# AccelZ
# AccelY
# analogio
# GyroX
# AccelX
# GyroY
# loading gyroscope data for session: 08_Seq2Session4
# AccelY
# GyroZ
# AccelX
# GyroY
# AccelZ
# GyroX
# timestamps
# analogio
# Warning: translated time has decreasing segments, switching to new version
# new version
# loading gyroscope data for session: 10_Seq2Session5
# GyroZ
# timestamps
# AccelX
# analogio
# AccelY
# AccelZ
# GyroX
# GyroY
# Warning: translated time has decreasing segments, switching to new version
# new version
# Working on session: 02_Seq2Session1
# Change of mind trials with remote content are: Index([], dtype='int64')
# Working on session: 04_Seq2Session2
# Change of mind trials with remote content are: Index([50], dtype='int64')
# [2025-12-17 16:09:02,608][WARNING]: Skipped checksum for file with hash: efe0da3c-2a85-7dcc-1866-f972e9d2298a, and path: /stelmo/nwb/raw/molly20220418_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: efe0da3c-2a85-7dcc-1866-f972e9d2298a, and path: /stelmo/nwb/raw/molly20220418_.nwb
# [2025-12-17 16:09:02,621][WARNING]: Skipped checksum for file with hash: efe0da3c-2a85-7dcc-1866-f972e9d2298a, and path: /stelmo/nwb/raw/molly20220418_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: efe0da3c-2a85-7dcc-1866-f972e9d2298a, and path: /stelmo/nwb/raw/molly20220418_.nwb
# [2025-12-17 16:09:02,649][WARNING]: Skipped checksum for file with hash: efe0da3c-2a85-7dcc-1866-f972e9d2298a, and path: /stelmo/nwb/raw/molly20220418_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: efe0da3c-2a85-7dcc-1866-f972e9d2298a, and path: /stelmo/nwb/raw/molly20220418_.nwb
# [2025-12-17 16:09:02,662][WARNING]: Skipped checksum for file with hash: efe0da3c-2a85-7dcc-1866-f972e9d2298a, and path: /stelmo/nwb/raw/molly20220418_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: efe0da3c-2a85-7dcc-1866-f972e9d2298a, and path: /stelmo/nwb/raw/molly20220418_.nwb
# ================================================================================
# LOADING ARTHUR SESSION
# ================================================================================
#
# Raw data:
#   Position: 807 frames
#   IMU: 1,033,321 samples (with sample-and-hold)
#
# Sample-and-hold removal:
#   Unique samples: 3,591
#   Repeat factor: 287.8×
#
# Sampling rates:
#   IMU: 100.0 Hz
#   Camera: 23.4 Hz
#
# Duration:
#   IMU: 34.4 s (0.6 min)
#   Camera: 34.4 s (0.6 min)
#   Time overlap: 34.4 s
#
# Unit conversions (IMU mode: 2d):
#   Gyro Z: [-365.9, 456.0] deg/s
#   Accel X: [-19.60, 19.58] m/s²
#   Accel Y: [-8.13, 19.58] m/s²
#   LED separation: 5.96 cm
#   Arena: 1.35 × 1.75 m
#
# ================================================================================
# ✓ Data ready for trodestrack
# ================================================================================
#
# Data successfully saved to /stelmo/shijie/gyro/tracking_molly20220418.nwb_04_Seq2Session2_trial50_result.pkl
# Working on session: 06_Seq2Session3
# Change of mind trials with remote content are: Index([12, 39], dtype='int64')
# [2025-12-17 16:09:03,493][WARNING]: Skipped checksum for file with hash: efe0da3c-2a85-7dcc-1866-f972e9d2298a, and path: /stelmo/nwb/raw/molly20220418_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: efe0da3c-2a85-7dcc-1866-f972e9d2298a, and path: /stelmo/nwb/raw/molly20220418_.nwb
# [2025-12-17 16:09:03,507][WARNING]: Skipped checksum for file with hash: efe0da3c-2a85-7dcc-1866-f972e9d2298a, and path: /stelmo/nwb/raw/molly20220418_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: efe0da3c-2a85-7dcc-1866-f972e9d2298a, and path: /stelmo/nwb/raw/molly20220418_.nwb
# [2025-12-17 16:09:03,536][WARNING]: Skipped checksum for file with hash: efe0da3c-2a85-7dcc-1866-f972e9d2298a, and path: /stelmo/nwb/raw/molly20220418_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: efe0da3c-2a85-7dcc-1866-f972e9d2298a, and path: /stelmo/nwb/raw/molly20220418_.nwb
# [2025-12-17 16:09:03,550][WARNING]: Skipped checksum for file with hash: efe0da3c-2a85-7dcc-1866-f972e9d2298a, and path: /stelmo/nwb/raw/molly20220418_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: efe0da3c-2a85-7dcc-1866-f972e9d2298a, and path: /stelmo/nwb/raw/molly20220418_.nwb
# ================================================================================
# LOADING ARTHUR SESSION
# ================================================================================
#
# Raw data:
#   Position: 928 frames
#   IMU: 1,188,031 samples (with sample-and-hold)
#
# Sample-and-hold removal:
#   Unique samples: 4,118
#   Repeat factor: 288.5×
#
# Sampling rates:
#   IMU: 100.0 Hz
#   Camera: 23.4 Hz
#
# Duration:
#   IMU: 39.6 s (0.7 min)
#   Camera: 39.6 s (0.7 min)
#   Time overlap: 39.6 s
#
# Unit conversions (IMU mode: 2d):
#   Gyro Z: [-353.9, 371.5] deg/s
#   Accel X: [-19.29, 19.58] m/s²
#   Accel Y: [-16.81, 19.58] m/s²
#   LED separation: 6.62 cm
#   Arena: 1.91 × 1.48 m
#
# ================================================================================
# ✓ Data ready for trodestrack
# ================================================================================
#
# Data successfully saved to /stelmo/shijie/gyro/tracking_molly20220418.nwb_06_Seq2Session3_trial12_result.pkl
# [2025-12-17 16:09:04,304][WARNING]: Skipped checksum for file with hash: efe0da3c-2a85-7dcc-1866-f972e9d2298a, and path: /stelmo/nwb/raw/molly20220418_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: efe0da3c-2a85-7dcc-1866-f972e9d2298a, and path: /stelmo/nwb/raw/molly20220418_.nwb
# [2025-12-17 16:09:04,318][WARNING]: Skipped checksum for file with hash: efe0da3c-2a85-7dcc-1866-f972e9d2298a, and path: /stelmo/nwb/raw/molly20220418_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: efe0da3c-2a85-7dcc-1866-f972e9d2298a, and path: /stelmo/nwb/raw/molly20220418_.nwb
# [2025-12-17 16:09:04,343][WARNING]: Skipped checksum for file with hash: efe0da3c-2a85-7dcc-1866-f972e9d2298a, and path: /stelmo/nwb/raw/molly20220418_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: efe0da3c-2a85-7dcc-1866-f972e9d2298a, and path: /stelmo/nwb/raw/molly20220418_.nwb
# [2025-12-17 16:09:04,356][WARNING]: Skipped checksum for file with hash: efe0da3c-2a85-7dcc-1866-f972e9d2298a, and path: /stelmo/nwb/raw/molly20220418_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: efe0da3c-2a85-7dcc-1866-f972e9d2298a, and path: /stelmo/nwb/raw/molly20220418_.nwb
# ================================================================================
# LOADING ARTHUR SESSION
# ================================================================================
#
# Raw data:
#   Position: 1,372 frames
#   IMU: 1,758,241 samples (with sample-and-hold)
#
# Sample-and-hold removal:
#   Unique samples: 6,101
#   Repeat factor: 288.2×
#
# Sampling rates:
#   IMU: 100.0 Hz
#   Camera: 23.4 Hz
#
# Duration:
#   IMU: 58.6 s (1.0 min)
#   Camera: 58.6 s (1.0 min)
#   Time overlap: 58.6 s
#
# Unit conversions (IMU mode: 2d):
#   Gyro Z: [-384.6, 338.3] deg/s
#   Accel X: [-19.60, 19.58] m/s²
#   Accel Y: [-11.03, 19.58] m/s²
#   LED separation: 6.01 cm
#   Arena: 1.20 × 1.78 m
#
# ================================================================================
# ✓ Data ready for trodestrack
# ================================================================================
#
# Data successfully saved to /stelmo/shijie/gyro/tracking_molly20220418.nwb_06_Seq2Session3_trial39_result.pkl
# Working on session: 08_Seq2Session4
# Change of mind trials with remote content are: Index([17], dtype='int64')
# Skipping trial 17 since no imu data found
# molly20220418_.nwb 08_Seq2Session4 17
# Working on session: 10_Seq2Session5
# Change of mind trials with remote content are: Index([17, 28, 39], dtype='int64')
# Skipping trial 17 since no imu data found
# molly20220418_.nwb 10_Seq2Session5 17
# [2025-12-17 16:09:05,650][WARNING]: Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# Skipping trial 28 since no imu data found
# molly20220418_.nwb 10_Seq2Session5 28
# Skipping trial 39 since no imu data found
# molly20220418_.nwb 10_Seq2Session5 39
# Data successfully saved to /stelmo/shijie/gyro/tracking_molly20220418.nwb_result.pkl
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.5.1 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'core' version 2.4.0 because version 2.7.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.2.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'ndx-franklab-novela' version 0.1.0 because version 0.2.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_0' has data shape (132843, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_1' has data shape (49114, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_10' has data shape (126927, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_2' has data shape (113271, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_3' has data shape (44711, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_4' has data shape (128851, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_5' has data shape (44359, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_6' has data shape (127295, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_7' has data shape (44299, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_8' has data shape (171463, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_9' has data shape (47038, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# *nwb_file_name *epoch    epoch_name     position_inter
# +------------+ +-------+ +------------+ +------------+
# molly20220419_ 1         01_Seq2Sleep1  pos 0 valid ti
# molly20220419_ 2         02_Seq2Session pos 1 valid ti
# molly20220419_ 3         03_Seq2Sleep2  pos 2 valid ti
# molly20220419_ 4         04_Seq2Session pos 3 valid ti
# molly20220419_ 5         05_Seq2Sleep3  pos 4 valid ti
# molly20220419_ 6         06_Seq2Session pos 5 valid ti
# molly20220419_ 7         07_Seq2Sleep4  pos 6 valid ti
# molly20220419_ 8         08_Seq2Session pos 7 valid ti
# molly20220419_ 9         09_Seq2Sleep5  pos 8 valid ti
# molly20220419_ 10        10_Seq2Session pos 9 valid ti
# molly20220419_ 11        11_Seq2Sleep6  pos 10 valid t
#  (Total: 11)
#
# loading gyroscope data for session: 02_Seq2Session1
# GyroY
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/rec_to_binaries/read_binaries.py:73: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   return np.dtype(typearr)
# AccelY
# analogio
# GyroX
# AccelX
# timestamps
# AccelZ
# GyroZ
# loading gyroscope data for session: 04_Seq2Session2
# AccelY
# GyroY
# AccelX
# GyroX
# timestamps
# GyroZ
# analogio
# AccelZ
# loading gyroscope data for session: 06_Seq2Session3
# analogio
# GyroX
# GyroY
# AccelZ
# timestamps
# GyroZ
# AccelY
# AccelX
# loading gyroscope data for session: 08_Seq2Session4
# GyroZ
# AccelZ
# AccelY
# GyroX
# AccelX
# GyroY
# timestamps
# analogio
# loading gyroscope data for session: 10_Seq2Session5
# GyroX
# AccelX
# AccelY
# GyroY
# timestamps
# analogio
# GyroZ
# AccelZ
# Working on session: 02_Seq2Session1
# Change of mind trials with remote content are: Index([52, 59], dtype='int64')
# [2025-12-17 16:18:06,921][WARNING]: Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# [2025-12-17 16:18:06,935][WARNING]: Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.5.1 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'core' version 2.4.0 because version 2.7.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.2.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'ndx-franklab-novela' version 0.1.0 because version 0.2.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_0' has data shape (132843, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_1' has data shape (49114, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_10' has data shape (126927, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_2' has data shape (113271, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_3' has data shape (44711, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_4' has data shape (128851, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_5' has data shape (44359, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_6' has data shape (127295, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_7' has data shape (44299, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_8' has data shape (171463, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_9' has data shape (47038, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# [2025-12-17 16:18:23,601][WARNING]: Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# [2025-12-17 16:18:23,617][WARNING]: Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# ================================================================================
# LOADING ARTHUR SESSION
# ================================================================================
#
# Raw data:
#   Position: 1,143 frames
#   IMU: 1,464,511 samples (with sample-and-hold)
#
# Sample-and-hold removal:
#   Unique samples: 5,079
#   Repeat factor: 288.3×
#
# Sampling rates:
#   IMU: 100.0 Hz
#   Camera: 23.4 Hz
#
# Duration:
#   IMU: 48.8 s (0.8 min)
#   Camera: 48.8 s (0.8 min)
#   Time overlap: 48.8 s
#
# Unit conversions (IMU mode: 2d):
#   Gyro Z: [-450.9, 254.7] deg/s
#   Accel X: [-19.60, 19.58] m/s²
#   Accel Y: [-9.55, 19.58] m/s²
#   LED separation: 6.60 cm
#   Arena: 1.58 × 1.78 m
#
# ================================================================================
# ✓ Data ready for trodestrack
# ================================================================================
#
# Data successfully saved to /stelmo/shijie/gyro/tracking_molly20220419.nwb_02_Seq2Session1_trial52_result.pkl
# [2025-12-17 16:18:27,559][WARNING]: Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# [2025-12-17 16:18:27,572][WARNING]: Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# [2025-12-17 16:18:27,599][WARNING]: Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# [2025-12-17 16:18:27,612][WARNING]: Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# ================================================================================
# LOADING ARTHUR SESSION
# ================================================================================
#
# Raw data:
#   Position: 1,069 frames
#   IMU: 1,369,711 samples (with sample-and-hold)
#
# Sample-and-hold removal:
#   Unique samples: 4,752
#   Repeat factor: 288.2×
#
# Sampling rates:
#   IMU: 100.0 Hz
#   Camera: 23.4 Hz
#
# Duration:
#   IMU: 45.7 s (0.8 min)
#   Camera: 45.6 s (0.8 min)
#   Time overlap: 45.6 s
#
# Unit conversions (IMU mode: 2d):
#   Gyro Z: [-417.0, 285.9] deg/s
#   Accel X: [-19.60, 19.58] m/s²
#   Accel Y: [-9.55, 19.58] m/s²
#   LED separation: 5.53 cm
#   Arena: 1.69 × 1.77 m
#
# ================================================================================
# ✓ Data ready for trodestrack
# ================================================================================
#
# Data successfully saved to /stelmo/shijie/gyro/tracking_molly20220419.nwb_02_Seq2Session1_trial59_result.pkl
# Working on session: 04_Seq2Session2
# Change of mind trials with remote content are: Index([], dtype='int64')
# Working on session: 06_Seq2Session3
# Change of mind trials with remote content are: Index([50], dtype='int64')
# [2025-12-17 16:18:31,295][WARNING]: Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# [2025-12-17 16:18:31,307][WARNING]: Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# [2025-12-17 16:18:31,333][WARNING]: Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# [2025-12-17 16:18:31,346][WARNING]: Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# ================================================================================
# LOADING ARTHUR SESSION
# ================================================================================
#
# Raw data:
#   Position: 797 frames
#   IMU: 1,021,591 samples (with sample-and-hold)
#
# Sample-and-hold removal:
#   Unique samples: 3,544
#   Repeat factor: 288.3×
#
# Sampling rates:
#   IMU: 100.0 Hz
#   Camera: 23.4 Hz
#
# Duration:
#   IMU: 34.1 s (0.6 min)
#   Camera: 34.0 s (0.6 min)
#   Time overlap: 34.0 s
#
# Unit conversions (IMU mode: 2d):
#   Gyro Z: [-308.6, 504.9] deg/s
#   Accel X: [-19.60, 19.58] m/s²
#   Accel Y: [-8.41, 19.58] m/s²
#   LED separation: 6.25 cm
#   Arena: 1.41 × 1.77 m
#
# ================================================================================
# ✓ Data ready for trodestrack
# ================================================================================
#
# Data successfully saved to /stelmo/shijie/gyro/tracking_molly20220419.nwb_06_Seq2Session3_trial50_result.pkl
# Working on session: 08_Seq2Session4
# Change of mind trials with remote content are: Index([], dtype='int64')
# Working on session: 10_Seq2Session5
# Change of mind trials with remote content are: Index([23], dtype='int64')
# [2025-12-17 16:18:37,938][WARNING]: Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# [2025-12-17 16:18:37,948][WARNING]: Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# [2025-12-17 16:18:37,972][WARNING]: Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# [2025-12-17 16:18:37,982][WARNING]: Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: ef8ca030-42c4-48b8-a231-4fec2a621ce9, and path: /stelmo/nwb/raw/molly20220419_.nwb
# ================================================================================
# LOADING ARTHUR SESSION
# ================================================================================
#
# Raw data:
#   Position: 954 frames
#   IMU: 1,221,721 samples (with sample-and-hold)
#
# Sample-and-hold removal:
#   Unique samples: 4,239
#   Repeat factor: 288.2×
#
# Sampling rates:
#   IMU: 100.0 Hz
#   Camera: 23.4 Hz
#
# Duration:
#   IMU: 40.7 s (0.7 min)
#   Camera: 40.7 s (0.7 min)
#   Time overlap: 40.7 s
#
# Unit conversions (IMU mode: 2d):
#   Gyro Z: [-368.0, 530.6] deg/s
#   Accel X: [-19.60, 19.58] m/s²
#   Accel Y: [-15.63, 19.58] m/s²
#   LED separation: 6.05 cm
#   Arena: 1.41 × 1.91 m
#
# ================================================================================
# ✓ Data ready for trodestrack
# ================================================================================
# [2025-12-17 16:18:41,578][WARNING]: Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# Data successfully saved to /stelmo/shijie/gyro/tracking_molly20220419.nwb_10_Seq2Session5_trial23_result.pkl
# Data successfully saved to /stelmo/shijie/gyro/tracking_molly20220419.nwb_result.pkl
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.5.1 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'core' version 2.4.0 because version 2.7.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.2.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'ndx-franklab-novela' version 0.1.0 because version 0.2.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_0' has data shape (119355, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_1' has data shape (13414, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_10' has data shape (182234, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_11' has data shape (52750, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_12' has data shape (121169, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_2' has data shape (151951, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_3' has data shape (50611, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_4' has data shape (119628, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_5' has data shape (52567, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_6' has data shape (122833, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_7' has data shape (53214, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_8' has data shape (158782, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_9' has data shape (53661, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# *nwb_file_name *epoch    epoch_name     position_inter
# +------------+ +-------+ +------------+ +------------+
# molly20220420_ 1         01_Seq2Sleep1  pos 0 valid ti
# molly20220420_ 2         02_Seq2Session pos 1 valid ti
# molly20220420_ 3         03_Seq2Sleep2  pos 2 valid ti
# molly20220420_ 4         04_Seq2Session pos 3 valid ti
# molly20220420_ 5         05_Seq2Sleep3  pos 4 valid ti
# molly20220420_ 6         06_Seq2Session pos 5 valid ti
# molly20220420_ 7         07_Seq2Sleep4  pos 6 valid ti
# molly20220420_ 8         08_Seq2Session pos 7 valid ti
# molly20220420_ 9         09_Seq2Sleep5  pos 8 valid ti
# molly20220420_ 10        10_Seq2Session pos 9 valid ti
# molly20220420_ 11        11_Seq2Sleep6  pos 10 valid t
# molly20220420_ 12        12_Seq2Session pos 11 valid t
#    ...
#  (Total: 13)
#
# loading gyroscope data for session: 02_Seq2Session1
# GyroY
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/rec_to_binaries/read_binaries.py:73: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   return np.dtype(typearr)
# analogio
# AccelZ
# GyroX
# AccelY
# GyroZ
# timestamps
# AccelX
# loading gyroscope data for session: 04_Seq2Session2
# AccelZ
# GyroX
# GyroY
# GyroZ
# timestamps
# analogio
# AccelX
# AccelY
# loading gyroscope data for session: 06_Seq2Session3
# GyroY
# AccelY
# GyroX
# timestamps
# AccelX
# analogio
# AccelZ
# GyroZ
# loading gyroscope data for session: 08_Seq2Session4
# timestamps
# GyroX
# GyroY
# AccelZ
# GyroZ
# AccelY
# analogio
# AccelX
# Warning: translated time has decreasing segments, switching to new version
# new version
# loading gyroscope data for session: 10_Seq2Session5
# timestamps
# AccelX
# AccelY
# analogio
# GyroZ
# GyroY
# AccelZ
# GyroX
# Warning: translated time has decreasing segments, switching to new version
# new version
# loading gyroscope data for session: 12_Seq2Session6
# GyroY
# AccelY
# AccelX
# GyroX
# timestamps
# analogio
# GyroZ
# AccelZ
# Warning: translated time has decreasing segments, switching to new version
# new version
# Working on session: 02_Seq2Session1
# Change of mind trials with remote content are: Index([], dtype='int64')
# Working on session: 04_Seq2Session2
# Change of mind trials with remote content are: Index([73], dtype='int64')
# [2025-12-17 16:32:21,698][WARNING]: Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# [2025-12-17 16:32:21,712][WARNING]: Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.5.1 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'core' version 2.4.0 because version 2.7.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.2.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'ndx-franklab-novela' version 0.1.0 because version 0.2.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_0' has data shape (119355, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_1' has data shape (13414, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_10' has data shape (182234, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_11' has data shape (52750, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_12' has data shape (121169, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_2' has data shape (151951, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_3' has data shape (50611, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_4' has data shape (119628, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_5' has data shape (52567, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_6' has data shape (122833, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_7' has data shape (53214, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_8' has data shape (158782, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_9' has data shape (53661, 4) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# [2025-12-17 16:32:39,178][WARNING]: Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# [2025-12-17 16:32:39,190][WARNING]: Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# ================================================================================
# LOADING ARTHUR SESSION
# ================================================================================
#
# Raw data:
#   Position: 1,579 frames
#   IMU: 2,553,511 samples (with sample-and-hold)
#
# Sample-and-hold removal:
#   Unique samples: 8,855
#   Repeat factor: 288.4×
#
# Sampling rates:
#   IMU: 100.0 Hz
#   Camera: 23.4 Hz
#
# Duration:
#   IMU: 85.1 s (1.4 min)
#   Camera: 85.1 s (1.4 min)
#   Time overlap: 85.1 s
#
# Unit conversions (IMU mode: 2d):
#   Gyro Z: [-1115.1, 1170.0] deg/s
#   Accel X: [-19.60, 19.58] m/s²
#   Accel Y: [-13.46, 19.58] m/s²
#   LED separation: 6.02 cm
#   Arena: 0.83 × 1.93 m
#
# ================================================================================
# ✓ Data ready for trodestrack
# ================================================================================
#
# Data successfully saved to /stelmo/shijie/gyro/tracking_molly20220420.nwb_04_Seq2Session2_trial73_result.pkl
# Working on session: 06_Seq2Session3
# Change of mind trials with remote content are: Index([], dtype='int64')
# Working on session: 08_Seq2Session4
# Change of mind trials with remote content are: Index([63, 64], dtype='int64')
# [2025-12-17 16:32:43,356][WARNING]: Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# [2025-12-17 16:32:43,368][WARNING]: Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# [2025-12-17 16:32:43,391][WARNING]: Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# [2025-12-17 16:32:43,401][WARNING]: Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# ================================================================================
# LOADING ARTHUR SESSION
# ================================================================================
#
# Raw data:
#   Position: 1,328 frames
#   IMU: 1,701,391 samples (with sample-and-hold)
#
# Sample-and-hold removal:
#   Unique samples: 5,908
#   Repeat factor: 288.0×
#
# Sampling rates:
#   IMU: 100.0 Hz
#   Camera: 23.4 Hz
#
# Duration:
#   IMU: 56.7 s (0.9 min)
#   Camera: 56.7 s (0.9 min)
#   Time overlap: 56.7 s
#
# Unit conversions (IMU mode: 2d):
#   Gyro Z: [-290.1, 386.1] deg/s
#   Accel X: [-19.60, 19.58] m/s²
#   Accel Y: [-7.33, 19.58] m/s²
#   LED separation: 5.94 cm
#   Arena: 1.58 × 1.86 m
#
# ================================================================================
# ✓ Data ready for trodestrack
# ================================================================================
#
# Data successfully saved to /stelmo/shijie/gyro/tracking_molly20220420.nwb_08_Seq2Session4_trial63_result.pkl
# [2025-12-17 16:32:47,381][WARNING]: Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# [2025-12-17 16:32:47,394][WARNING]: Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# [2025-12-17 16:32:47,418][WARNING]: Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# [2025-12-17 16:32:47,430][WARNING]: Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# ================================================================================
# LOADING ARTHUR SESSION
# ================================================================================
#
# Raw data:
#   Position: 1,369 frames
#   IMU: 1,754,611 samples (with sample-and-hold)
#
# Sample-and-hold removal:
#   Unique samples: 6,099
#   Repeat factor: 287.7×
#
# Sampling rates:
#   IMU: 100.0 Hz
#   Camera: 23.4 Hz
#
# Duration:
#   IMU: 58.5 s (1.0 min)
#   Camera: 58.5 s (1.0 min)
#   Time overlap: 58.5 s
#
# Unit conversions (IMU mode: 2d):
#   Gyro Z: [-290.6, 269.4] deg/s
#   Accel X: [-19.60, 19.58] m/s²
#   Accel Y: [-6.54, 19.58] m/s²
#   LED separation: 6.05 cm
#   Arena: 1.66 × 1.89 m
#
# ================================================================================
# ✓ Data ready for trodestrack
# ================================================================================
#
# Data successfully saved to /stelmo/shijie/gyro/tracking_molly20220420.nwb_08_Seq2Session4_trial64_result.pkl
# Working on session: 10_Seq2Session5
# Change of mind trials with remote content are: Index([66], dtype='int64')
# [2025-12-17 16:32:51,123][WARNING]: Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# [2025-12-17 16:32:51,136][WARNING]: Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# [2025-12-17 16:32:51,162][WARNING]: Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# [2025-12-17 16:32:51,175][WARNING]: Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# ================================================================================
# LOADING ARTHUR SESSION
# ================================================================================
#
# Raw data:
#   Position: 1,230 frames
#   IMU: 1,576,201 samples (with sample-and-hold)
#
# Sample-and-hold removal:
#   Unique samples: 5,465
#   Repeat factor: 288.4×
#
# Sampling rates:
#   IMU: 100.0 Hz
#   Camera: 23.4 Hz
#
# Duration:
#   IMU: 52.5 s (0.9 min)
#   Camera: 52.5 s (0.9 min)
#   Time overlap: 52.5 s
#
# Unit conversions (IMU mode: 2d):
#   Gyro Z: [-329.4, 276.5] deg/s
#   Accel X: [-19.60, 19.58] m/s²
#   Accel Y: [-7.70, 19.58] m/s²
#   LED separation: 5.91 cm
#   Arena: 0.76 × 1.91 m
#
# ================================================================================
# ✓ Data ready for trodestrack
# ================================================================================
#
# Data successfully saved to /stelmo/shijie/gyro/tracking_molly20220420.nwb_10_Seq2Session5_trial66_result.pkl
# Working on session: 12_Seq2Session6
# Change of mind trials with remote content are: Index([29], dtype='int64')
# [2025-12-17 16:32:54,850][WARNING]: Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# [2025-12-17 16:32:54,862][WARNING]: Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# [2025-12-17 16:32:54,889][WARNING]: Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# [2025-12-17 16:32:54,901][WARNING]: Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 54317ee3-2aef-be98-7df1-a36bfc743ed2, and path: /stelmo/nwb/raw/molly20220420_.nwb
# ================================================================================
# LOADING ARTHUR SESSION
# ================================================================================
#
# Raw data:
#   Position: 976 frames
#   IMU: 1,250,281 samples (with sample-and-hold)
#
# Sample-and-hold removal:
#   Unique samples: 4,341
#   Repeat factor: 288.0×
#
# Sampling rates:
#   IMU: 100.0 Hz
#   Camera: 23.4 Hz
#
# Duration:
#   IMU: 41.7 s (0.7 min)
#   Camera: 41.6 s (0.7 min)
#   Time overlap: 41.6 s
#
# Unit conversions (IMU mode: 2d):
#   Gyro Z: [-345.1, 323.7] deg/s
#   Accel X: [-19.60, 19.58] m/s²
#   Accel Y: [-14.27, 19.58] m/s²
#   LED separation: 6.60 cm
#   Arena: 1.40 × 1.91 m
#
# ================================================================================
# ✓ Data ready for trodestrack
# ================================================================================
#
# Data successfully saved to /stelmo/shijie/gyro/tracking_molly20220420.nwb_12_Seq2Session6_trial29_result.pkl
# Data successfully saved to /stelmo/shijie/gyro/tracking_molly20220420.nwb_result.pkl

# %%
# %debug
# Out:
# > /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pandas/core/indexing.py(1718)_get_list_axis()
#    1716         except IndexError as err:
#    1717             # re-raise with different error message, e.g. test_getitem_ndarray_3d
# -> 1718             raise IndexError("positional indexers are out-of-bounds") from err
#    1719
#    1720     def _getitem_axis(self, key, axis: AxisInt):
# ipdb>  u
# > /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pandas/core/indexing.py(1744)_getitem_axis()
#    1742         # a list of integers
#    1743         elif is_list_like_indexer(key):
# -> 1744             return self._get_list_axis(key, axis=axis)
#    1745
#    1746         # a single integer
# ipdb>  u
# > /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pandas/core/indexing.py(1192)__getitem__()
#    1190             maybe_callable = com.apply_if_callable(key, self.obj)
#    1191             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192             return self._getitem_axis(maybe_callable, axis=axis)
#    1193
#    1194     def _is_scalar_access(self, key: tuple):
# ipdb>  u
# > /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/trodestrack/data/load_arthur_session.py(427)load_arthur_session()
#     425     # Remove IMU sample-and-hold
#     426     unique_indices = find_unique_samples(imu_df["Headstage_GyroZ"].values)
# --> 427     imu_unique = imu_df.iloc[unique_indices]
#     428
#     429     if verbose:
# ipdb>  imu_df
# Empty DataFrame
# Columns: [Headstage_GyroX, Headstage_GyroY, Headstage_GyroZ, Headstage_AccelX, Headstage_AccelY, Headstage_AccelZ]
# Index: []
# ipdb>  u
# > /home/shijiegu/Documents/spyglass/src/spyglass/shijiegu/gyroscope.py(289)prepare_data_for_tracking()
#     287     pq.write_table(extracted_pos_data, pos_path)
#     288
# --> 289     packed_data = load_arthur_session(pos_path, imu_path,
#     290         verbose = True,
#     291         imu_mode = "2d",  # Use full 6-axis IMU
# ipdb>  df
# Empty DataFrame
# Columns: [Headstage_GyroX, Headstage_GyroY, Headstage_GyroZ, Headstage_AccelX, Headstage_AccelY, Headstage_AccelZ]
# Index: []
# ipdb>  extracted_imu_data
# {'AccelX': array([], dtype=float32), 'AccelY': array([], dtype=float32), 'AccelZ': array([], dtype=float32), 'GyroX': array([], dtype=float32), 'GyroY': array([], dtype=float32), 'GyroZ': array([], dtype=float32), 'timestamps': array([], dtype=float64)}
# ipdb>  u
# > /home/shijiegu/Documents/spyglass/src/spyglass/shijiegu/gyroscope.py(401)batch_process_animal()
#     399                 pos_path = f'{output_folder}position_{nwb_file_name}_{session_name}_trial{trial1}.parquet' # the path to write pos data to
#     400
# --> 401                 packed_data = prepare_data_for_tracking(
#     402                     extracted_imu_data, extracted_pos_data, imu_path, pos_path, meters_per_pixel)
#     403                 inferred_position_x, inferred_position_y, inferred_heading, result = run_trodes_tracking(packed_data)
# ipdb>  trial
# 17
# ipdb>  t0
# 1650320543.448689
# ipdb>  t1
# 1650320578.4177868
# ipdb>  data_day[session_name]
# {'AccelY': {'description': 'One analog IO channel. Continuous sampling.', 'byte_order': 'little endian', 'original_file': '20220418_molly_08_Seq2Session4.rec', 'clockrate': '30000', 'trodes_version': '1.9.1', 'compile_date': 'Feb 28 2020', 'compile_time': '14:23:45', 'qt_version': '5.9.8', 'commit_tag': 'heads/Release_1.9.1-0-g6c661e4-dirty', 'controller_firmware': '3.17', 'headstage_firmware': '-1', 'controller_serialnum': '65535 65535', 'headstage_serialnum': '-1', 'autosettle': '-1', 'smartref': '-1', 'gyro': '-1', 'accelerometer': '-1', 'magnetometer': '-1', 'time_offset': '0', 'system_time_at_creation': '1650320083391', 'timestamp_at_creation': '75291567', 'first_timestamp': '75917256', 'direction': 'input', 'id': 'Headstage_AccelY', 'display_order': '66', 'fields': '<voltage int16>', 'data': array([(   0,), (   0,), (   0,), ..., (9651,), (9651,), (9651,)],
#       dtype=[('voltage', '<i2')])}, 'GyroZ': {'description': 'One analog IO channel. Continuous sampling.', 'byte_order': 'little endian', 'original_file': '20220418_molly_08_Seq2Session4.rec', 'clockrate': '30000', 'trodes_version': '1.9.1', 'compile_date': 'Feb 28 2020', 'compile_time': '14:23:45', 'qt_version': '5.9.8', 'commit_tag': 'heads/Release_1.9.1-0-g6c661e4-dirty', 'controller_firmware': '3.17', 'headstage_firmware': '-1', 'controller_serialnum': '65535 65535', 'headstage_serialnum': '-1', 'autosettle': '-1', 'smartref': '-1', 'gyro': '-1', 'accelerometer': '-1', 'magnetometer': '-1', 'time_offset': '0', 'system_time_at_creation': '1650320083391', 'timestamp_at_creation': '75291567', 'first_timestamp': '75917256', 'direction': 'input', 'id': 'Headstage_GyroZ', 'display_order': '70', 'fields': '<voltage int16>', 'data': array([(   0,), (   0,), (   0,), ..., (-185,), (-185,), (-185,)],
#       dtype=[('voltage', '<i2')])}, 'AccelX': {'description': 'One analog IO channel. Continuous sampling.', 'byte_order': 'little endian', 'original_file': '20220418_molly_08_Seq2Session4.rec', 'clockrate': '30000', 'trodes_version': '1.9.1', 'compile_date': 'Feb 28 2020', 'compile_time': '14:23:45', 'qt_version': '5.9.8', 'commit_tag': 'heads/Release_1.9.1-0-g6c661e4-dirty', 'controller_firmware': '3.17', 'headstage_firmware': '-1', 'controller_serialnum': '65535 65535', 'headstage_serialnum': '-1', 'autosettle': '-1', 'smartref': '-1', 'gyro': '-1', 'accelerometer': '-1', 'magnetometer': '-1', 'time_offset': '0', 'system_time_at_creation': '1650320083391', 'timestamp_at_creation': '75291567', 'first_timestamp': '75917256', 'direction': 'input', 'id': 'Headstage_AccelX', 'display_order': '65', 'fields': '<voltage int16>', 'data': array([(    0,), (    0,), (    0,), ..., (-1445,), (-1445,), (-1445,)],
#       dtype=[('voltage', '<i2')])}, 'GyroY': {'description': 'One analog IO channel. Continuous sampling.', 'byte_order': 'little endian', 'original_file': '20220418_molly_08_Seq2Session4.rec', 'clockrate': '30000', 'trodes_version': '1.9.1', 'compile_date': 'Feb 28 2020', 'compile_time': '14:23:45', 'qt_version': '5.9.8', 'commit_tag': 'heads/Release_1.9.1-0-g6c661e4-dirty', 'controller_firmware': '3.17', 'headstage_firmware': '-1', 'controller_serialnum': '65535 65535', 'headstage_serialnum': '-1', 'autosettle': '-1', 'smartref': '-1', 'gyro': '-1', 'accelerometer': '-1', 'magnetometer': '-1', 'time_offset': '0', 'system_time_at_creation': '1650320083391', 'timestamp_at_creation': '75291567', 'first_timestamp': '75917256', 'direction': 'input', 'id': 'Headstage_GyroY', 'display_order': '69', 'fields': '<voltage int16>', 'data': array([(  0,), (  0,), (  0,), ..., (699,), (699,), (699,)],
#       dtype=[('voltage', '<i2')])}, 'AccelZ': {'description': 'One analog IO channel. Continuous sampling.', 'byte_order': 'little endian', 'original_file': '20220418_molly_08_Seq2Session4.rec', 'clockrate': '30000', 'trodes_version': '1.9.1', 'compile_date': 'Feb 28 2020', 'compile_time': '14:23:45', 'qt_version': '5.9.8', 'commit_tag': 'heads/Release_1.9.1-0-g6c661e4-dirty', 'controller_firmware': '3.17', 'headstage_firmware': '-1', 'controller_serialnum': '65535 65535', 'headstage_serialnum': '-1', 'autosettle': '-1', 'smartref': '-1', 'gyro': '-1', 'accelerometer': '-1', 'magnetometer': '-1', 'time_offset': '0', 'system_time_at_creation': '1650320083391', 'timestamp_at_creation': '75291567', 'first_timestamp': '75917256', 'direction': 'input', 'id': 'Headstage_AccelZ', 'display_order': '67', 'fields': '<voltage int16>', 'data': array([(     0,), (     0,), (     0,), ..., (-11820,), (-11820,),
#        (-11820,)], dtype=[('voltage', '<i2')])}, 'GyroX': {'description': 'One analog IO channel. Continuous sampling.', 'byte_order': 'little endian', 'original_file': '20220418_molly_08_Seq2Session4.rec', 'clockrate': '30000', 'trodes_version': '1.9.1', 'compile_date': 'Feb 28 2020', 'compile_time': '14:23:45', 'qt_version': '5.9.8', 'commit_tag': 'heads/Release_1.9.1-0-g6c661e4-dirty', 'controller_firmware': '3.17', 'headstage_firmware': '-1', 'controller_serialnum': '65535 65535', 'headstage_serialnum': '-1', 'autosettle': '-1', 'smartref': '-1', 'gyro': '-1', 'accelerometer': '-1', 'magnetometer': '-1', 'time_offset': '0', 'system_time_at_creation': '1650320083391', 'timestamp_at_creation': '75291567', 'first_timestamp': '75917256', 'direction': 'input', 'id': 'Headstage_GyroX', 'display_order': '68', 'fields': '<voltage int16>', 'data': array([(  0,), (  0,), (  0,), ..., (254,), (254,), (254,)],
#       dtype=[('voltage', '<i2')])}, 'timestamps': {'description': 'Analog IO timestamps', 'byte_order': 'little endian', 'original_file': '20220418_molly_08_Seq2Session4.rec', 'clockrate': '30000', 'trodes_version': '1.9.1', 'compile_date': 'Feb 28 2020', 'compile_time': '14:23:45', 'qt_version': '5.9.8', 'commit_tag': 'heads/Release_1.9.1-0-g6c661e4-dirty', 'controller_firmware': '3.17', 'headstage_firmware': '-1', 'controller_serialnum': '65535 65535', 'headstage_serialnum': '-1', 'autosettle': '-1', 'smartref': '-1', 'gyro': '-1', 'accelerometer': '-1', 'magnetometer': '-1', 'time_offset': '0', 'system_time_at_creation': '1650320083391', 'timestamp_at_creation': '75291567', 'first_timestamp': '75917256', 'fields': '<time uint32>', 'data': array([( 75917256,), ( 75917257,), ( 75917258,), ..., (134553125,),
#        (134553126,), (134553127,)], dtype=[('time', '<u4')]), 'unix': array([1.65030418e+09, 1.65030418e+09, 1.65030418e+09, ...,
#        1.65032206e+09, 1.65032206e+09, 1.65032206e+09])}}
# ipdb>  data_day[session_name].keys()
# dict_keys(['AccelY', 'GyroZ', 'AccelX', 'GyroY', 'AccelZ', 'GyroX', 'timestamps'])
# ipdb>  data_day[session_name]['timestamps'][0]
# *** KeyError: 0
# ipdb>  data_day[session_name]['timestamps']
# {'description': 'Analog IO timestamps', 'byte_order': 'little endian', 'original_file': '20220418_molly_08_Seq2Session4.rec', 'clockrate': '30000', 'trodes_version': '1.9.1', 'compile_date': 'Feb 28 2020', 'compile_time': '14:23:45', 'qt_version': '5.9.8', 'commit_tag': 'heads/Release_1.9.1-0-g6c661e4-dirty', 'controller_firmware': '3.17', 'headstage_firmware': '-1', 'controller_serialnum': '65535 65535', 'headstage_serialnum': '-1', 'autosettle': '-1', 'smartref': '-1', 'gyro': '-1', 'accelerometer': '-1', 'magnetometer': '-1', 'time_offset': '0', 'system_time_at_creation': '1650320083391', 'timestamp_at_creation': '75291567', 'first_timestamp': '75917256', 'fields': '<time uint32>', 'data': array([( 75917256,), ( 75917257,), ( 75917258,), ..., (134553125,),
#        (134553126,), (134553127,)], dtype=[('time', '<u4')]), 'unix': array([1.65030418e+09, 1.65030418e+09, 1.65030418e+09, ...,
#        1.65032206e+09, 1.65032206e+09, 1.65032206e+09])}
# ipdb>  data_day[session_name]['timestamps']['unix']
# array([1.65030418e+09, 1.65030418e+09, 1.65030418e+09, ...,
#        1.65032206e+09, 1.65032206e+09, 1.65032206e+09])
# ipdb>  data_day[session_name]['timestamps']['unix'][0]
# 1650304179.7857132
# ipdb>  t0
# 1650320543.448689
# ipdb>  data_day[session_name]['timestamps']['unix'][-1]
# 1650322058.7821565
# ipdb>  mask = data_day[session_name]['timestamps']['unix']>= t0 & data_day[session_name]['timestamps']['unix'] < t1
# *** TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# ipdb>  mask = np.logical_and(data_day[session_name]['timestamps']['unix']>= t0, data_day[session_name]['timestamps']['unix'] < t1)
# ipdb>  np.sum(mask)
# 0
# ipdb>  t1
# 1650320578.4177868
# ipdb>  t0
# 1650320543.448689
# ipdb>  mask = data_day[session_name]['timestamps']['unix'] >= t0
# ipdb>  np.sum(mask)
# 25165071
# ipdb>  mask = data_day[session_name]['timestamps']['unix'] < t1
# ipdb>  np.sum(mask)
# 33470801
# ipdb>  t1
# 1650320578.4177868
# ipdb>  t0
# 1650320543.448689
# ipdb>  data_day[session_name]['timestamps']['unix']
# array([1.65030418e+09, 1.65030418e+09, 1.65030418e+09, ...,
#        1.65032206e+09, 1.65032206e+09, 1.65032206e+09])
# ipdb>  np.max(np.abs(np.diff(data_day[session_name]['timestamps']['unix'])))
# 15924.462356328964
# ipdb>  np.min(np.abs(np.diff(data_day[session_name]['timestamps']['unix'])))
# 3.2901763916015625e-05
# ipdb>  15924/3600
# 4.423333333333333
# ipdb>  np.max((np.diff(data_day[session_name]['timestamps']['unix']))
# *** SyntaxError: '(' was never closed
# ipdb>  np.max(np.diff(data_day[session_name]['timestamps']['unix']))
# 15924.462356328964
# ipdb>  np.min(np.diff(data_day[session_name]['timestamps']['unix']))
# 3.2901763916015625e-05
# ipdb>  exit

# %%
animal = 'julio'
output_folder = '/stelmo/shijie/gyro/'
parent_folder = f"/stelmo/shijie/recording_pilot/{animal}/preprocessing/"
success = batch_process_animal(animal, list_of_days_animals[animal], output_folder, parent_folder)
# Out:
# [2025-12-16 11:07:54,475][WARNING]: Skipped checksum for file with hash: 3dff66e2-eb07-6220-818c-94b5d5928dc0, and path: /stelmo/nwb/raw/julio20230731_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 3dff66e2-eb07-6220-818c-94b5d5928dc0, and path: /stelmo/nwb/raw/julio20230731_.nwb
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_0' has data shape (42527, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_1' has data shape (61323, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_10' has data shape (107873, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_11' has data shape (67617, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_12' has data shape (56896, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_2' has data shape (107844, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_3' has data shape (66015, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_4' has data shape (135775, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_5' has data shape (41108, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_6' has data shape (90249, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_7' has data shape (61821, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_8' has data shape (80539, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_9' has data shape (60567, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# *nwb_file_name *epoch    epoch_name     position_inter
# +------------+ +-------+ +------------+ +------------+
# julio20230731_ 1         01_Seq2Sleep1  pos 0 valid ti
# julio20230731_ 2         02_Seq2Session pos 1 valid ti
# julio20230731_ 3         03_Seq2Sleep2  pos 2 valid ti
# julio20230731_ 4         04_Seq2Session pos 3 valid ti
# julio20230731_ 5         05_Seq2Sleep3  pos 4 valid ti
# julio20230731_ 6         06_Seq2Session pos 5 valid ti
# julio20230731_ 7         07_Seq2Sleep4  pos 6 valid ti
# julio20230731_ 8         08_Seq2Session pos 7 valid ti
# julio20230731_ 9         09_Seq2Sleep5  pos 8 valid ti
# julio20230731_ 10        10_Seq2Session pos 9 valid ti
# julio20230731_ 11        11_Seq2Sleep6  pos 10 valid t
# julio20230731_ 12        12_Seq2Session pos 11 valid t
#    ...
#  (Total: 13)
#
# loading gyroscope data for session: 02_Seq2Session1
# AccelX
# analogio
# AccelY
# GyroZ
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/rec_to_binaries/read_binaries.py:73: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   return np.dtype(typearr)
# GyroY
# AccelZ
# GyroX
# timestamps
# loading gyroscope data for session: 04_Seq2Session2
# GyroZ
# AccelZ
# timestamps
# analogio
# GyroX
# AccelX
# AccelY
# GyroY
# Warning: translated time has decreasing segments, switching to new version
# new version
# loading gyroscope data for session: 06_Seq2Session3
# AccelX
# GyroZ
# AccelY
# analogio
# AccelZ
# GyroX
# timestamps
# GyroY
# loading gyroscope data for session: 08_Seq2Session4
# AccelX
# GyroZ
# timestamps
# AccelY
# AccelZ
# GyroX
# analogio
# GyroY
# loading gyroscope data for session: 10_Seq2Session5
# AccelY
# GyroZ
# analogio
# AccelX
# GyroX
# AccelZ
# GyroY
# timestamps
# loading gyroscope data for session: 12_Seq2Session6
# GyroZ
# AccelY
# analogio
# AccelX
# timestamps
# GyroX
# AccelZ
# GyroY
# Working on session: 02_Seq2Session1
# Change of mind trials with remote content are: Index([22], dtype='int64')
# [2025-12-16 11:13:01,342][WARNING]: Skipped checksum for file with hash: 3dff66e2-eb07-6220-818c-94b5d5928dc0, and path: /stelmo/nwb/raw/julio20230731_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 3dff66e2-eb07-6220-818c-94b5d5928dc0, and path: /stelmo/nwb/raw/julio20230731_.nwb
# [2025-12-16 11:13:01,356][WARNING]: Skipped checksum for file with hash: 3dff66e2-eb07-6220-818c-94b5d5928dc0, and path: /stelmo/nwb/raw/julio20230731_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 3dff66e2-eb07-6220-818c-94b5d5928dc0, and path: /stelmo/nwb/raw/julio20230731_.nwb
# [2025-12-16 11:13:01,388][WARNING]: Skipped checksum for file with hash: 3dff66e2-eb07-6220-818c-94b5d5928dc0, and path: /stelmo/nwb/raw/julio20230731_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 3dff66e2-eb07-6220-818c-94b5d5928dc0, and path: /stelmo/nwb/raw/julio20230731_.nwb
# [2025-12-16 11:13:01,403][WARNING]: Skipped checksum for file with hash: 3dff66e2-eb07-6220-818c-94b5d5928dc0, and path: /stelmo/nwb/raw/julio20230731_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 3dff66e2-eb07-6220-818c-94b5d5928dc0, and path: /stelmo/nwb/raw/julio20230731_.nwb
# ================================================================================
# LOADING ARTHUR SESSION
# ================================================================================
#
# Raw data:
#   Position: 1,347 frames
#   IMU: 1,725,336 samples (with sample-and-hold)
#
# Sample-and-hold removal:
#   Unique samples: 5,989
#   Repeat factor: 288.1×
#
# Sampling rates:
#   IMU: 100.0 Hz
#   Camera: 23.4 Hz
#
# Duration:
#   IMU: 57.5 s (1.0 min)
#   Camera: 57.5 s (1.0 min)
#   Time overlap: 57.5 s
#
# Unit conversions (IMU mode: 2d):
#   Gyro Z: [-286.7, 285.2] deg/s
#   Accel X: [-19.60, 19.58] m/s²
#   Accel Y: [-9.38, 19.58] m/s²
#   LED separation: 6.82 cm
#   Arena: 1.29 × 1.75 m
#
# ================================================================================
# ✓ Data ready for trodestrack
# ================================================================================
#
# Data successfully saved to /stelmo/shijie/gyro/tracking_julio20230731.nwb_02_Seq2Session1_trial22_result.pkl
# Working on session: 04_Seq2Session2
# Change of mind trials with remote content are: Index([12, 15], dtype='int64')
# [2025-12-16 11:13:02,702][WARNING]: Skipped checksum for file with hash: 3dff66e2-eb07-6220-818c-94b5d5928dc0, and path: /stelmo/nwb/raw/julio20230731_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 3dff66e2-eb07-6220-818c-94b5d5928dc0, and path: /stelmo/nwb/raw/julio20230731_.nwb
# [2025-12-16 11:13:02,717][WARNING]: Skipped checksum for file with hash: 3dff66e2-eb07-6220-818c-94b5d5928dc0, and path: /stelmo/nwb/raw/julio20230731_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 3dff66e2-eb07-6220-818c-94b5d5928dc0, and path: /stelmo/nwb/raw/julio20230731_.nwb
# [2025-12-16 11:13:02,747][WARNING]: Skipped checksum for file with hash: 3dff66e2-eb07-6220-818c-94b5d5928dc0, and path: /stelmo/nwb/raw/julio20230731_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 3dff66e2-eb07-6220-818c-94b5d5928dc0, and path: /stelmo/nwb/raw/julio20230731_.nwb
# [2025-12-16 11:13:02,762][WARNING]: Skipped checksum for file with hash: 3dff66e2-eb07-6220-818c-94b5d5928dc0, and path: /stelmo/nwb/raw/julio20230731_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 3dff66e2-eb07-6220-818c-94b5d5928dc0, and path: /stelmo/nwb/raw/julio20230731_.nwb
# ================================================================================
# LOADING ARTHUR SESSION
# ================================================================================
#
# Raw data:
#   Position: 1,401 frames
#   IMU: 1,794,961 samples (with sample-and-hold)
#
# Sample-and-hold removal:
#   Unique samples: 6,239
#   Repeat factor: 287.7×
#
# Sampling rates:
#   IMU: 100.0 Hz
#   Camera: 23.4 Hz
#
# Duration:
#   IMU: 59.8 s (1.0 min)
#   Camera: 59.8 s (1.0 min)
#   Time overlap: 59.8 s
#
# Unit conversions (IMU mode: 2d):
#   Gyro Z: [-280.2, 186.7] deg/s
#   Accel X: [-19.60, 19.15] m/s²
#   Accel Y: [-8.87, 19.58] m/s²
#   LED separation: 6.67 cm
#   Arena: 1.30 × 1.85 m
#
# ================================================================================
# ✓ Data ready for trodestrack
# ================================================================================
#
# Data successfully saved to /stelmo/shijie/gyro/tracking_julio20230731.nwb_04_Seq2Session2_trial12_result.pkl
# [2025-12-16 11:13:07,253][WARNING]: Skipped checksum for file with hash: 3dff66e2-eb07-6220-818c-94b5d5928dc0, and path: /stelmo/nwb/raw/julio20230731_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 3dff66e2-eb07-6220-818c-94b5d5928dc0, and path: /stelmo/nwb/raw/julio20230731_.nwb
# [2025-12-16 11:13:07,268][WARNING]: Skipped checksum for file with hash: 3dff66e2-eb07-6220-818c-94b5d5928dc0, and path: /stelmo/nwb/raw/julio20230731_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 3dff66e2-eb07-6220-818c-94b5d5928dc0, and path: /stelmo/nwb/raw/julio20230731_.nwb
# [2025-12-16 11:13:07,300][WARNING]: Skipped checksum for file with hash: 3dff66e2-eb07-6220-818c-94b5d5928dc0, and path: /stelmo/nwb/raw/julio20230731_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 3dff66e2-eb07-6220-818c-94b5d5928dc0, and path: /stelmo/nwb/raw/julio20230731_.nwb
# [2025-12-16 11:13:07,317][WARNING]: Skipped checksum for file with hash: 3dff66e2-eb07-6220-818c-94b5d5928dc0, and path: /stelmo/nwb/raw/julio20230731_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 3dff66e2-eb07-6220-818c-94b5d5928dc0, and path: /stelmo/nwb/raw/julio20230731_.nwb
# ================================================================================
# LOADING ARTHUR SESSION
# ================================================================================
#
# Raw data:
#   Position: 1,125 frames
#   IMU: 1,441,505 samples (with sample-and-hold)
#
# Sample-and-hold removal:
#   Unique samples: 5,005
#   Repeat factor: 288.0×
#
# Sampling rates:
#   IMU: 100.0 Hz
#   Camera: 23.4 Hz
#
# Duration:
#   IMU: 48.0 s (0.8 min)
#   Camera: 48.0 s (0.8 min)
#   Time overlap: 48.0 s
#
# Unit conversions (IMU mode: 2d):
#   Gyro Z: [-285.5, 221.7] deg/s
#   Accel X: [-19.60, 19.58] m/s²
#   Accel Y: [-11.33, 19.58] m/s²
#   LED separation: 6.18 cm
#   Arena: 1.28 × 1.73 m
#
# ================================================================================
# ✓ Data ready for trodestrack
# ================================================================================
# [2025-12-16 11:13:10,980][WARNING]: Skipped checksum for file with hash: e1952e07-f706-9154-f4b6-1e4795d731b7, and path: /stelmo/nwb/raw/julio20230801_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: e1952e07-f706-9154-f4b6-1e4795d731b7, and path: /stelmo/nwb/raw/julio20230801_.nwb
# Data successfully saved to /stelmo/shijie/gyro/tracking_julio20230731.nwb_04_Seq2Session2_trial15_result.pkl
# Working on session: 06_Seq2Session3
# Change of mind trials with remote content are: Index([], dtype='int64')
# Working on session: 08_Seq2Session4
# Change of mind trials with remote content are: Index([], dtype='int64')
# Working on session: 10_Seq2Session5
# Change of mind trials with remote content are: Index([], dtype='int64')
# Working on session: 12_Seq2Session6
# Change of mind trials with remote content are: Index([], dtype='int64')
# Data successfully saved to /stelmo/shijie/gyro/tracking_julio20230731.nwb_result.pkl
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_0' has data shape (31971, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_1' has data shape (53532, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_10' has data shape (81439, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_11' has data shape (48953, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_12' has data shape (63149, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_2' has data shape (75993, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_3' has data shape (54240, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_4' has data shape (139057, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_5' has data shape (49252, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_6' has data shape (196027, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_7' has data shape (48201, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_8' has data shape (105674, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_9' has data shape (44499, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# *nwb_file_name *epoch    epoch_name     position_inter
# +------------+ +-------+ +------------+ +------------+
# julio20230801_ 1         01_Seq2Sleep1  pos 0 valid ti
# julio20230801_ 2         02_Seq2Session pos 1 valid ti
# julio20230801_ 3         03_Seq2Sleep2  pos 2 valid ti
# julio20230801_ 4         04_Seq2Session pos 3 valid ti
# julio20230801_ 5         05_Seq2Sleep3  pos 4 valid ti
# julio20230801_ 6         06_Seq2Session pos 5 valid ti
# julio20230801_ 7         07_Seq2Sleep4  pos 6 valid ti
# julio20230801_ 8         08_Seq2Session pos 7 valid ti
# julio20230801_ 9         09_Seq2Sleep5  pos 8 valid ti
# julio20230801_ 10        10_Seq2Session pos 9 valid ti
# julio20230801_ 11        11_Seq2Sleep6  pos 10 valid t
# julio20230801_ 12        12_Seq2Session pos 11 valid t
#    ...
#  (Total: 13)
#
# loading gyroscope data for session: 02_Seq2Session1
# GyroZ
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/rec_to_binaries/read_binaries.py:73: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   return np.dtype(typearr)
# AccelZ
# AccelY
# timestamps
# GyroY
# AccelX
# GyroX
# analogio
# loading gyroscope data for session: 04_Seq2Session2
# GyroX
# AccelZ
# GyroY
# analogio
# AccelX
# GyroZ
# AccelY
# timestamps
# loading gyroscope data for session: 06_Seq2Session3
# GyroX
# AccelZ
# analogio
# GyroY
# GyroZ
# timestamps
# AccelY
# AccelX
# loading gyroscope data for session: 08_Seq2Session4
# AccelY
# GyroZ
# AccelX
# GyroY
# timestamps
# analogio
# AccelZ
# GyroX
# loading gyroscope data for session: 10_Seq2Session5
# GyroX
# analogio
# AccelY
# AccelX
# GyroY
# GyroZ
# AccelZ
# timestamps
# loading gyroscope data for session: 12_Seq2Session6
# analogio
# GyroZ
# AccelX
# AccelY
# timestamps
# AccelZ
# GyroX
# GyroY
# Working on session: 02_Seq2Session1
# Change of mind trials with remote content are: Index([], dtype='int64')
# Working on session: 04_Seq2Session2
# Change of mind trials with remote content are: Index([], dtype='int64')
# Working on session: 06_Seq2Session3
# Change of mind trials with remote content are: Index([11], dtype='int64')
# [2025-12-16 11:24:14,821][WARNING]: Skipped checksum for file with hash: e1952e07-f706-9154-f4b6-1e4795d731b7, and path: /stelmo/nwb/raw/julio20230801_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: e1952e07-f706-9154-f4b6-1e4795d731b7, and path: /stelmo/nwb/raw/julio20230801_.nwb
# [2025-12-16 11:24:14,836][WARNING]: Skipped checksum for file with hash: e1952e07-f706-9154-f4b6-1e4795d731b7, and path: /stelmo/nwb/raw/julio20230801_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: e1952e07-f706-9154-f4b6-1e4795d731b7, and path: /stelmo/nwb/raw/julio20230801_.nwb
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_0' has data shape (31971, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_1' has data shape (53532, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_10' has data shape (81439, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_11' has data shape (48953, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_12' has data shape (63149, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_2' has data shape (75993, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_3' has data shape (54240, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_4' has data shape (139057, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_5' has data shape (49252, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_6' has data shape (196027, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_7' has data shape (48201, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_8' has data shape (105674, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_9' has data shape (44499, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# [2025-12-16 11:24:31,914][WARNING]: Skipped checksum for file with hash: e1952e07-f706-9154-f4b6-1e4795d731b7, and path: /stelmo/nwb/raw/julio20230801_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: e1952e07-f706-9154-f4b6-1e4795d731b7, and path: /stelmo/nwb/raw/julio20230801_.nwb
# [2025-12-16 11:24:31,929][WARNING]: Skipped checksum for file with hash: e1952e07-f706-9154-f4b6-1e4795d731b7, and path: /stelmo/nwb/raw/julio20230801_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: e1952e07-f706-9154-f4b6-1e4795d731b7, and path: /stelmo/nwb/raw/julio20230801_.nwb
# ================================================================================
# LOADING ARTHUR SESSION
# ================================================================================
#
# Raw data:
#   Position: 1,078 frames
#   IMU: 1,380,332 samples (with sample-and-hold)
#
# Sample-and-hold removal:
#   Unique samples: 4,796
#   Repeat factor: 287.8×
#
# Sampling rates:
#   IMU: 100.0 Hz
#   Camera: 23.4 Hz
#
# Duration:
#   IMU: 46.0 s (0.8 min)
#   Camera: 46.0 s (0.8 min)
#   Time overlap: 46.0 s
#
# Unit conversions (IMU mode: 2d):
#   Gyro Z: [-304.9, 262.5] deg/s
#   Accel X: [-19.60, 18.29] m/s²
#   Accel Y: [-8.77, 19.58] m/s²
#   LED separation: 6.45 cm
#   Arena: 1.83 × 1.47 m
#
# ================================================================================
# ✓ Data ready for trodestrack
# ================================================================================
# [2025-12-16 11:24:35,934][WARNING]: Skipped checksum for file with hash: 34c31a78-2a75-9620-9976-1eda1ec40580, and path: /stelmo/nwb/raw/julio20230802_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 34c31a78-2a75-9620-9976-1eda1ec40580, and path: /stelmo/nwb/raw/julio20230802_.nwb
# Data successfully saved to /stelmo/shijie/gyro/tracking_julio20230801.nwb_06_Seq2Session3_trial11_result.pkl
# Working on session: 08_Seq2Session4
# Change of mind trials with remote content are: Index([], dtype='int64')
# Working on session: 10_Seq2Session5
# Change of mind trials with remote content are: Index([], dtype='int64')
# Working on session: 12_Seq2Session6
# Change of mind trials with remote content are: Index([], dtype='int64')
# Data successfully saved to /stelmo/shijie/gyro/tracking_julio20230801.nwb_result.pkl
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_0' has data shape (42207, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_1' has data shape (68794, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_2' has data shape (177024, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_3' has data shape (55838, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_4' has data shape (112017, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_5' has data shape (56740, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_6' has data shape (73895, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_7' has data shape (48539, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_8' has data shape (90069, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# *nwb_file_name *epoch    epoch_name     position_inter
# +------------+ +-------+ +------------+ +------------+
# julio20230802_ 1         01_Seq2Sleep1  pos 0 valid ti
# julio20230802_ 2         02_Seq2Session pos 1 valid ti
# julio20230802_ 3         03_Seq2Sleep2  pos 2 valid ti
# julio20230802_ 4         04_Seq2Session pos 3 valid ti
# julio20230802_ 5         05_Seq2Sleep3  pos 4 valid ti
# julio20230802_ 6         06_Seq2Session pos 5 valid ti
# julio20230802_ 7         07_Seq2Sleep4  pos 6 valid ti
# julio20230802_ 8         08_Seq2Session pos 7 valid ti
# julio20230802_ 9         09_Seq2Sleep5  pos 8 valid ti
#  (Total: 9)
#
# loading gyroscope data for session: 02_Seq2Session1
# analogio
# AccelZ
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/rec_to_binaries/read_binaries.py:73: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   return np.dtype(typearr)
# GyroZ
# GyroY
# AccelX
# AccelY
# timestamps
# GyroX
# loading gyroscope data for session: 04_Seq2Session2
# AccelZ
# timestamps
# GyroZ
# analogio
# GyroX
# AccelX
# AccelY
# GyroY
# Warning: translated time has decreasing segments, switching to new version
# new version
# loading gyroscope data for session: 06_Seq2Session3
# GyroY
# AccelY
# timestamps
# AccelX
# GyroX
# analogio
# GyroZ
# AccelZ
# Warning: translated time has decreasing segments, switching to new version
# new version
# loading gyroscope data for session: 08_Seq2Session4
# timestamps
# AccelY
# GyroZ
# AccelX
# analogio
# GyroY
# AccelZ
# GyroX
# Working on session: 02_Seq2Session1
# Change of mind trials with remote content are: Index([], dtype='int64')
# Working on session: 04_Seq2Session2
# Change of mind trials with remote content are: Index([70], dtype='int64')
# [2025-12-16 11:33:31,844][WARNING]: Skipped checksum for file with hash: 34c31a78-2a75-9620-9976-1eda1ec40580, and path: /stelmo/nwb/raw/julio20230802_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 34c31a78-2a75-9620-9976-1eda1ec40580, and path: /stelmo/nwb/raw/julio20230802_.nwb
# [2025-12-16 11:33:31,858][WARNING]: Skipped checksum for file with hash: 34c31a78-2a75-9620-9976-1eda1ec40580, and path: /stelmo/nwb/raw/julio20230802_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 34c31a78-2a75-9620-9976-1eda1ec40580, and path: /stelmo/nwb/raw/julio20230802_.nwb
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_0' has data shape (42207, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_1' has data shape (68794, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_2' has data shape (177024, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_3' has data shape (55838, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_4' has data shape (112017, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_5' has data shape (56740, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_6' has data shape (73895, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_7' has data shape (48539, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_8' has data shape (90069, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# [2025-12-16 11:33:47,357][WARNING]: Skipped checksum for file with hash: 34c31a78-2a75-9620-9976-1eda1ec40580, and path: /stelmo/nwb/raw/julio20230802_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 34c31a78-2a75-9620-9976-1eda1ec40580, and path: /stelmo/nwb/raw/julio20230802_.nwb
# [2025-12-16 11:33:47,373][WARNING]: Skipped checksum for file with hash: 34c31a78-2a75-9620-9976-1eda1ec40580, and path: /stelmo/nwb/raw/julio20230802_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 34c31a78-2a75-9620-9976-1eda1ec40580, and path: /stelmo/nwb/raw/julio20230802_.nwb
# ================================================================================
# LOADING ARTHUR SESSION
# ================================================================================
#
# Raw data:
#   Position: 1,282 frames
#   IMU: 1,642,368 samples (with sample-and-hold)
#
# Sample-and-hold removal:
#   Unique samples: 5,707
#   Repeat factor: 287.8×
#
# Sampling rates:
#   IMU: 100.0 Hz
#   Camera: 23.4 Hz
#
# Duration:
#   IMU: 54.7 s (0.9 min)
#   Camera: 54.7 s (0.9 min)
#   Time overlap: 54.7 s
#
# Unit conversions (IMU mode: 2d):
#   Gyro Z: [-241.9, 304.9] deg/s
#   Accel X: [-19.60, 19.58] m/s²
#   Accel Y: [-11.43, 19.58] m/s²
#   LED separation: 6.05 cm
#   Arena: 1.81 × 1.82 m
#
# ================================================================================
# ✓ Data ready for trodestrack
# ================================================================================
#
# Data successfully saved to /stelmo/shijie/gyro/tracking_julio20230802.nwb_04_Seq2Session2_trial70_result.pkl
# Working on session: 06_Seq2Session3
# Change of mind trials with remote content are: Index([51], dtype='int64')
# [2025-12-16 11:33:58,014][WARNING]: Skipped checksum for file with hash: 34c31a78-2a75-9620-9976-1eda1ec40580, and path: /stelmo/nwb/raw/julio20230802_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 34c31a78-2a75-9620-9976-1eda1ec40580, and path: /stelmo/nwb/raw/julio20230802_.nwb
# [2025-12-16 11:33:58,027][WARNING]: Skipped checksum for file with hash: 34c31a78-2a75-9620-9976-1eda1ec40580, and path: /stelmo/nwb/raw/julio20230802_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 34c31a78-2a75-9620-9976-1eda1ec40580, and path: /stelmo/nwb/raw/julio20230802_.nwb
# [2025-12-16 11:33:58,057][WARNING]: Skipped checksum for file with hash: 34c31a78-2a75-9620-9976-1eda1ec40580, and path: /stelmo/nwb/raw/julio20230802_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 34c31a78-2a75-9620-9976-1eda1ec40580, and path: /stelmo/nwb/raw/julio20230802_.nwb
# [2025-12-16 11:33:58,072][WARNING]: Skipped checksum for file with hash: 34c31a78-2a75-9620-9976-1eda1ec40580, and path: /stelmo/nwb/raw/julio20230802_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 34c31a78-2a75-9620-9976-1eda1ec40580, and path: /stelmo/nwb/raw/julio20230802_.nwb
# ================================================================================
# LOADING ARTHUR SESSION
# ================================================================================
#
# Raw data:
#   Position: 1,322 frames
#   IMU: 1,693,691 samples (with sample-and-hold)
#
# Sample-and-hold removal:
#   Unique samples: 5,886
#   Repeat factor: 287.7×
#
# Sampling rates:
#   IMU: 100.0 Hz
#   Camera: 23.4 Hz
#
# Duration:
#   IMU: 56.4 s (0.9 min)
#   Camera: 56.5 s (0.9 min)
#   Time overlap: 56.4 s
#
# Unit conversions (IMU mode: 2d):
#   Gyro Z: [-355.0, 213.9] deg/s
#   Accel X: [-19.60, 19.58] m/s²
#   Accel Y: [-11.19, 19.58] m/s²
#   LED separation: 6.28 cm
#   Arena: 1.30 × 1.73 m
#
# ================================================================================
# ✓ Data ready for trodestrack
# ================================================================================
# [2025-12-16 11:34:02,006][WARNING]: Skipped checksum for file with hash: 18d64dab-8354-3ff0-1505-662ac37a5e83, and path: /stelmo/nwb/raw/julio20230803_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 18d64dab-8354-3ff0-1505-662ac37a5e83, and path: /stelmo/nwb/raw/julio20230803_.nwb
# Data successfully saved to /stelmo/shijie/gyro/tracking_julio20230802.nwb_06_Seq2Session3_trial51_result.pkl
# Working on session: 08_Seq2Session4
# Change of mind trials with remote content are: Index([], dtype='int64')
# Data successfully saved to /stelmo/shijie/gyro/tracking_julio20230802.nwb_result.pkl
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_0' has data shape (42823, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_1' has data shape (56989, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_10' has data shape (65312, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_11' has data shape (61231, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_12' has data shape (79891, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_2' has data shape (86780, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_3' has data shape (61908, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_4' has data shape (237893, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_5' has data shape (55626, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_6' has data shape (110388, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_7' has data shape (62165, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_8' has data shape (28835, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_9' has data shape (56456, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# *nwb_file_name *epoch    epoch_name     position_inter
# ...
# *nwb_file_name *epoch    epoch_name     position_inter
# +------------+ +-------+ +------------+ +------------+
# julio20230804_ 1         01_Seq2Sleep1  pos 0 valid ti
# julio20230804_ 2         02_Seq2Session pos 1 valid ti
# julio20230804_ 3         03_Seq2Sleep2  pos 2 valid ti
# julio20230804_ 4         04_Seq2Session pos 3 valid ti
# julio20230804_ 5         05_Seq2Sleep3  pos 4 valid ti
# julio20230804_ 6         06_Seq2Session pos 5 valid ti
# julio20230804_ 7         07_Seq2Sleep4  pos 6 valid ti
# julio20230804_ 8         08_Seq2Session pos 7 valid ti
# julio20230804_ 9         09_Seq2Sleep5  pos 8 valid ti
# julio20230804_ 10        10_Seq2Session pos 9 valid ti
# julio20230804_ 11        11_Seq2Sleep6  pos 10 valid t
# julio20230804_ 12        12_Seq2Session pos 11 valid t
#    ...
#  (Total: 13)
#
# loading gyroscope data for session: 02_Seq2Session1
# AccelX
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/rec_to_binaries/read_binaries.py:73: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   return np.dtype(typearr)
# GyroZ
# timestamps
# analogio
# AccelY
# GyroX
# AccelZ
# GyroY
# loading gyroscope data for session: 04_Seq2Session2
# analogio
# GyroZ
# AccelY
# AccelX
# timestamps
# GyroX
# AccelZ
# GyroY
# Warning: translated time has decreasing segments, switching to new version
# new version
# loading gyroscope data for session: 06_Seq2Session3
# GyroX
# AccelZ
# GyroY
# GyroZ
# timestamps
# AccelY
# analogio
# AccelX
# loading gyroscope data for session: 08_Seq2Session4
# AccelX
# GyroZ
# timestamps
# AccelY
# GyroX
# AccelZ
# analogio
# GyroY
# loading gyroscope data for session: 10_Seq2Session5
# GyroX
# AccelX
# timestamps
# AccelY
# GyroY
# GyroZ
# AccelZ
# analogio
# loading gyroscope data for session: 12_Seq2Session6
# GyroZ
# AccelX
# timestamps
# AccelY
# GyroX
# AccelZ
# analogio
# GyroY
# Working on session: 02_Seq2Session1
# Change of mind trials with remote content are: Index([], dtype='int64')
# Working on session: 04_Seq2Session2
# Change of mind trials with remote content are: Index([70], dtype='int64')
# [2025-12-16 11:59:52,519][WARNING]: Skipped checksum for file with hash: 18dad81d-e9f2-cf9f-dc79-e72bd41309f7, and path: /stelmo/nwb/raw/julio20230804_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 18dad81d-e9f2-cf9f-dc79-e72bd41309f7, and path: /stelmo/nwb/raw/julio20230804_.nwb
# [2025-12-16 11:59:52,533][WARNING]: Skipped checksum for file with hash: 18dad81d-e9f2-cf9f-dc79-e72bd41309f7, and path: /stelmo/nwb/raw/julio20230804_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 18dad81d-e9f2-cf9f-dc79-e72bd41309f7, and path: /stelmo/nwb/raw/julio20230804_.nwb
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_0' has data shape (47047, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_1' has data shape (60002, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_10' has data shape (134105, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_11' has data shape (47878, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_12' has data shape (109940, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_2' has data shape (79191, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_3' has data shape (62385, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_4' has data shape (165190, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_5' has data shape (59962, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_6' has data shape (141734, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_7' has data shape (66969, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_8' has data shape (110337, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_9' has data shape (53477, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# [2025-12-16 12:00:09,760][WARNING]: Skipped checksum for file with hash: 18dad81d-e9f2-cf9f-dc79-e72bd41309f7, and path: /stelmo/nwb/raw/julio20230804_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 18dad81d-e9f2-cf9f-dc79-e72bd41309f7, and path: /stelmo/nwb/raw/julio20230804_.nwb
# [2025-12-16 12:00:09,776][WARNING]: Skipped checksum for file with hash: 18dad81d-e9f2-cf9f-dc79-e72bd41309f7, and path: /stelmo/nwb/raw/julio20230804_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 18dad81d-e9f2-cf9f-dc79-e72bd41309f7, and path: /stelmo/nwb/raw/julio20230804_.nwb
# ================================================================================
# LOADING ARTHUR SESSION
# ================================================================================
#
# Raw data:
#   Position: 1,151 frames
#   IMU: 1,474,181 samples (with sample-and-hold)
#
# Sample-and-hold removal:
#   Unique samples: 5,118
#   Repeat factor: 288.0×
#
# Sampling rates:
#   IMU: 100.0 Hz
#   Camera: 23.4 Hz
#
# Duration:
#   IMU: 49.1 s (0.8 min)
#   Camera: 49.1 s (0.8 min)
#   Time overlap: 49.1 s
#
# Unit conversions (IMU mode: 2d):
#   Gyro Z: [-241.2, 315.4] deg/s
#   Accel X: [-19.60, 19.58] m/s²
#   Accel Y: [-11.79, 18.51] m/s²
#   LED separation: 6.56 cm
#   Arena: 0.83 × 1.75 m
#
# ================================================================================
# ✓ Data ready for trodestrack
# ================================================================================
#
# Data successfully saved to /stelmo/shijie/gyro/tracking_julio20230804.nwb_04_Seq2Session2_trial70_result.pkl
# Working on session: 06_Seq2Session3
# Change of mind trials with remote content are: Index([], dtype='int64')
# Working on session: 08_Seq2Session4
# Change of mind trials with remote content are: Index([], dtype='int64')
# Working on session: 10_Seq2Session5
# Change of mind trials with remote content are: Index([], dtype='int64')
# Working on session: 12_Seq2Session6
# Change of mind trials with remote content are: Index([37], dtype='int64')
# [2025-12-16 12:00:14,098][WARNING]: Skipped checksum for file with hash: 18dad81d-e9f2-cf9f-dc79-e72bd41309f7, and path: /stelmo/nwb/raw/julio20230804_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 18dad81d-e9f2-cf9f-dc79-e72bd41309f7, and path: /stelmo/nwb/raw/julio20230804_.nwb
# [2025-12-16 12:00:14,112][WARNING]: Skipped checksum for file with hash: 18dad81d-e9f2-cf9f-dc79-e72bd41309f7, and path: /stelmo/nwb/raw/julio20230804_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 18dad81d-e9f2-cf9f-dc79-e72bd41309f7, and path: /stelmo/nwb/raw/julio20230804_.nwb
# [2025-12-16 12:00:14,142][WARNING]: Skipped checksum for file with hash: 18dad81d-e9f2-cf9f-dc79-e72bd41309f7, and path: /stelmo/nwb/raw/julio20230804_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 18dad81d-e9f2-cf9f-dc79-e72bd41309f7, and path: /stelmo/nwb/raw/julio20230804_.nwb
# [2025-12-16 12:00:14,155][WARNING]: Skipped checksum for file with hash: 18dad81d-e9f2-cf9f-dc79-e72bd41309f7, and path: /stelmo/nwb/raw/julio20230804_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 18dad81d-e9f2-cf9f-dc79-e72bd41309f7, and path: /stelmo/nwb/raw/julio20230804_.nwb
# ================================================================================
# LOADING ARTHUR SESSION
# ================================================================================
#
# Raw data:
#   Position: 1,041 frames
#   IMU: 1,332,686 samples (with sample-and-hold)
#
# Sample-and-hold removal:
#   Unique samples: 4,629
#   Repeat factor: 287.9×
#
# Sampling rates:
#   IMU: 100.0 Hz
#   Camera: 23.4 Hz
#
# Duration:
#   IMU: 44.4 s (0.7 min)
#   Camera: 44.4 s (0.7 min)
#   Time overlap: 44.4 s
#
# Unit conversions (IMU mode: 2d):
#   Gyro Z: [-317.7, 175.3] deg/s
#   Accel X: [-19.60, 19.58] m/s²
#   Accel Y: [-5.79, 19.58] m/s²
#   LED separation: 6.19 cm
#   Arena: 1.36 × 1.74 m
#
# ================================================================================
# ✓ Data ready for trodestrack
# ================================================================================
# [2025-12-16 12:00:17,641][WARNING]: Skipped checksum for file with hash: 937cfe06-f973-2d35-fdc4-50d27a10a1ba, and path: /stelmo/nwb/raw/julio20230805_.nwb
# WARNING:datajoint:Skipped checksum for file with hash: 937cfe06-f973-2d35-fdc4-50d27a10a1ba, and path: /stelmo/nwb/raw/julio20230805_.nwb
# Data successfully saved to /stelmo/shijie/gyro/tracking_julio20230804.nwb_12_Seq2Session6_trial37_result.pkl
# Data successfully saved to /stelmo/shijie/gyro/tracking_julio20230804.nwb_result.pkl
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_0' has data shape (37468, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_1' has data shape (57607, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_2' has data shape (178134, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_3' has data shape (53039, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_4' has data shape (99286, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_5' has data shape (24434, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_6' has data shape (56786, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_7' has data shape (129027, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_8' has data shape (50395, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_9' has data shape (69573, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "

# %%
#%debug
# Out:
# > /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pandas/core/indexing.py(1718)_get_list_axis()
#    1716         except IndexError as err:
#    1717             # re-raise with different error message, e.g. test_getitem_ndarray_3d
# -> 1718             raise IndexError("positional indexers are out-of-bounds") from err
#    1719
#    1720     def _getitem_axis(self, key, axis: AxisInt):
# ipdb>  u
# > /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pandas/core/indexing.py(1744)_getitem_axis()
#    1742         # a list of integers
#    1743         elif is_list_like_indexer(key):
# -> 1744             return self._get_list_axis(key, axis=axis)
#    1745
#    1746         # a single integer
# ipdb>  u
# > /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/pandas/core/indexing.py(1192)__getitem__()
#    1190             maybe_callable = com.apply_if_callable(key, self.obj)
#    1191             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192             return self._getitem_axis(maybe_callable, axis=axis)
#    1193
#    1194     def _is_scalar_access(self, key: tuple):
# ipdb>  u
# > /home/shijiegu/anaconda3/envs/spyglass/lib/python3.10/site-packages/trodestrack/data/load_arthur_session.py(427)load_arthur_session()
#     425     # Remove IMU sample-and-hold
#     426     unique_indices = find_unique_samples(imu_df["Headstage_GyroZ"].values)
# --> 427     imu_unique = imu_df.iloc[unique_indices]
#     428
#     429     if verbose:
# ipdb>  u
# > /home/shijiegu/Documents/spyglass/src/spyglass/shijiegu/gyroscope.py(166)prepare_data_for_tracking()
#     164     pq.write_table(extracted_pos_data, pos_path)
#     165
# --> 166     packed_data = load_arthur_session(pos_path, imu_path,
#     167         verbose = True,
#     168         imu_mode = "2d",  # Use full 6-axis IMU
# ipdb>  pos_path
# '/stelmo/shijie/gyro/position_julio20230731.nwb_04_Seq2Session2_trial12.parquet'
# ipdb>  imu_path
# '/stelmo/shijie/gyro/imu_julio20230731.nwb_04_Seq2Session2_trial12.parquet'
# ipdb>  exit

# %%
print(success)
# Out:
# 1
