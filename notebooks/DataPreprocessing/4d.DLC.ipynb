# %% [markdown]
# ### DLC

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import datajoint as dj

import spyglass.common as sgc
import spyglass.position.v1 as sgp

import numpy as np
import pandas as pd
import pynwb
from spyglass.position import PositionOutput

# ignore datajoint+jupyter async warnings
import warnings

warnings.simplefilter("ignore", category=DeprecationWarning)
warnings.simplefilter("ignore", category=ResourceWarning)

# %%
# !export DLC_PROJECT_DIR="/nimbus/deeplabcut/projects"
# !export DLC_VIDEO_DIR="/nimbus/deeplabcut/video"
# !export DLC_OUTPUT_DIR="/nimbus/deeplabcut/output"

# %% [markdown]
# #### 1. Body parts

# %%
bodyparts = ['earL','earR','tailBase']

# %% [markdown]
# #### 2. Video lists

# %%
video_list = [
    {"nwb_file_name": "klein20231101_.nwb", "epoch": 2},
]

# %% [markdown]
# #### 3. Setting up the project

# %%
team_name = 'Shijie Gu'  # If on lab DB, "LorenLab"
project_name = "Klein"
frames_per_video = 300

project_key = sgp.DLCProject.insert_new_project(
    project_name=project_name,
    bodyparts=bodyparts,
    lab_team=team_name,
    frames_per_video=frames_per_video,
    video_list=video_list,
    skip_duplicates=True,
)
# Out:
# 2025-10-03 09:56:36.239196: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-03 09:56:38.451818: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-03 09:56:43.847081: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/MATLAB/R2022b/bin/glnxa64
# 2025-10-03 09:56:43.847464: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/MATLAB/R2022b/bin/glnxa64
# 2025-10-03 09:56:43.847478: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Loading DLC 2.3.11...
# DLC loaded in light mode; you cannot use any GUI (labeling, relabeling and standalone GUI)
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# ndx-franklab-novela - cached version: 0.2.0, loaded version: 0.2.2
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_0' has data shape (37998, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_1' has data shape (71308, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_10' has data shape (93462, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_11' has data shape (73087, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_12' has data shape (61845, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_2' has data shape (222793, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_3' has data shape (83286, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_4' has data shape (150824, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_5' has data shape (69167, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_6' has data shape (160201, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_7' has data shape (74957, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_8' has data shape (106144, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_9' has data shape (72083, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/hdmf/spec/namespace.py:583: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# ndx-franklab-novela - cached version: 0.2.0, loaded version: 0.2.2
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_0' has data shape (37998, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_1' has data shape (71308, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_10' has data shape (93462, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_11' has data shape (73087, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_12' has data shape (61845, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_2' has data shape (222793, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_3' has data shape (83286, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_4' has data shape (150824, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_5' has data shape (69167, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_6' has data shape (160201, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_7' has data shape (74957, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_8' has data shape (106144, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/pynwb/behavior.py:48: UserWarning: SpatialSeries 'series_9' has data shape (72083, 6) which is not compliant with NWB 2.5 and greater. The second dimension should have length <= 3 to represent at most x, y, z.
#   warnings.warn("SpatialSeries '%s' has data shape %s which is not compliant with NWB 2.5 and greater. "
# [09:57:46][INFO] Spyglass: Finished converting 20231101_klein_02_Rev2Session1.1.h264
# [09:57:46][INFO] Spyglass: Checking packets match orig file: 20231101_klein_02_Rev2Session1
# Created "/stelmo/nwb/deeplabcut/projects/Klein-Shijie_Gu-2025-10-03/videos"
# Created "/stelmo/nwb/deeplabcut/projects/Klein-Shijie_Gu-2025-10-03/labeled-data"
# Created "/stelmo/nwb/deeplabcut/projects/Klein-Shijie_Gu-2025-10-03/training-datasets"
# Created "/stelmo/nwb/deeplabcut/projects/Klein-Shijie_Gu-2025-10-03/dlc-models"
# Copying the videos
# /stelmo/nwb/deeplabcut/projects/Klein-Shijie_Gu-2025-10-03/videos/20231101_klein_02_Rev2Session1.mp4
# Generated "/stelmo/nwb/deeplabcut/projects/Klein-Shijie_Gu-2025-10-03/config.yaml"
#
# A new project with name Klein-Shijie_Gu-2025-10-03 is created at /stelmo/nwb/deeplabcut/projects and a configurable file (config.yaml) is stored there. Change the parameters in this file to adapt to your project's needs.
#  Once you have changed the configuration file, use the function 'extract_frames' to select frames for labeling.
# . [OPTIONAL] Use the function 'add_new_videos' to add new videos to your project (at any stage).
# [10:01:14][WARNING] Spyglass: No training files to add

# %%
# comment this line out after you finish frame extraction for each project
sgp.DLCProject().run_extract_frames(project_key)
# Out:
# Config file read successfully.
# Do you want to extract (perhaps additional) frames for video: /stelmo/nwb/deeplabcut/projects/Klein-Shijie_Gu-2025-10-03/videos/20231101_klein_02_Rev2Session1.mp4 ?
# yes/no yes
# Extracting frames based on kmeans ...
# Kmeans-quantization based extracting of frames from 0.0  seconds to 2855.44  seconds.
# Extracting and downsampling... 71386  frames from the video.
# 71386it [09:15, 128.45it/s]
# Kmeans clustering ... (this might take a while)
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/skimage/_shared/utils.py:328: UserWarning: /stelmo/nwb/deeplabcut/projects/Klein-Shijie_Gu-2025-10-03/labeled-data/20231101_klein_02_Rev2Session1/img26740.png is a low contrast image
#   return func(*args, **kwargs)
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/skimage/_shared/utils.py:328: UserWarning: /stelmo/nwb/deeplabcut/projects/Klein-Shijie_Gu-2025-10-03/labeled-data/20231101_klein_02_Rev2Session1/img07998.png is a low contrast image
#   return func(*args, **kwargs)
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/skimage/_shared/utils.py:328: UserWarning: /stelmo/nwb/deeplabcut/projects/Klein-Shijie_Gu-2025-10-03/labeled-data/20231101_klein_02_Rev2Session1/img35600.png is a low contrast image
#   return func(*args, **kwargs)
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/skimage/_shared/utils.py:328: UserWarning: /stelmo/nwb/deeplabcut/projects/Klein-Shijie_Gu-2025-10-03/labeled-data/20231101_klein_02_Rev2Session1/img09742.png is a low contrast image
#   return func(*args, **kwargs)
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/skimage/_shared/utils.py:328: UserWarning: /stelmo/nwb/deeplabcut/projects/Klein-Shijie_Gu-2025-10-03/labeled-data/20231101_klein_02_Rev2Session1/img50008.png is a low contrast image
#   return func(*args, **kwargs)
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/skimage/_shared/utils.py:328: UserWarning: /stelmo/nwb/deeplabcut/projects/Klein-Shijie_Gu-2025-10-03/labeled-data/20231101_klein_02_Rev2Session1/img44783.png is a low contrast image
#   return func(*args, **kwargs)
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/skimage/_shared/utils.py:328: UserWarning: /stelmo/nwb/deeplabcut/projects/Klein-Shijie_Gu-2025-10-03/labeled-data/20231101_klein_02_Rev2Session1/img40888.png is a low contrast image
#   return func(*args, **kwargs)
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/skimage/_shared/utils.py:328: UserWarning: /stelmo/nwb/deeplabcut/projects/Klein-Shijie_Gu-2025-10-03/labeled-data/20231101_klein_02_Rev2Session1/img23790.png is a low contrast image
#   return func(*args, **kwargs)
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/skimage/_shared/utils.py:328: UserWarning: /stelmo/nwb/deeplabcut/projects/Klein-Shijie_Gu-2025-10-03/labeled-data/20231101_klein_02_Rev2Session1/img67725.png is a low contrast image
#   return func(*args, **kwargs)
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/skimage/_shared/utils.py:328: UserWarning: /stelmo/nwb/deeplabcut/projects/Klein-Shijie_Gu-2025-10-03/labeled-data/20231101_klein_02_Rev2Session1/img39582.png is a low contrast image
#   return func(*args, **kwargs)
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/skimage/_shared/utils.py:328: UserWarning: /stelmo/nwb/deeplabcut/projects/Klein-Shijie_Gu-2025-10-03/labeled-data/20231101_klein_02_Rev2Session1/img40527.png is a low contrast image
#   return func(*args, **kwargs)
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/skimage/_shared/utils.py:328: UserWarning: /stelmo/nwb/deeplabcut/projects/Klein-Shijie_Gu-2025-10-03/labeled-data/20231101_klein_02_Rev2Session1/img27181.png is a low contrast image
#   return func(*args, **kwargs)
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/skimage/_shared/utils.py:328: UserWarning: /stelmo/nwb/deeplabcut/projects/Klein-Shijie_Gu-2025-10-03/labeled-data/20231101_klein_02_Rev2Session1/img50522.png is a low contrast image
#   return func(*args, **kwargs)
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/skimage/_shared/utils.py:328: UserWarning: /stelmo/nwb/deeplabcut/projects/Klein-Shijie_Gu-2025-10-03/labeled-data/20231101_klein_02_Rev2Session1/img02143.png is a low contrast image
#   return func(*args, **kwargs)
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/skimage/_shared/utils.py:328: UserWarning: /stelmo/nwb/deeplabcut/projects/Klein-Shijie_Gu-2025-10-03/labeled-data/20231101_klein_02_Rev2Session1/img55470.png is a low contrast image
#   return func(*args, **kwargs)
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/skimage/_shared/utils.py:328: UserWarning: /stelmo/nwb/deeplabcut/projects/Klein-Shijie_Gu-2025-10-03/labeled-data/20231101_klein_02_Rev2Session1/img68375.png is a low contrast image
#   return func(*args, **kwargs)
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/skimage/_shared/utils.py:328: UserWarning: /stelmo/nwb/deeplabcut/projects/Klein-Shijie_Gu-2025-10-03/labeled-data/20231101_klein_02_Rev2Session1/img39430.png is a low contrast image
#   return func(*args, **kwargs)
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/skimage/_shared/utils.py:328: UserWarning: /stelmo/nwb/deeplabcut/projects/Klein-Shijie_Gu-2025-10-03/labeled-data/20231101_klein_02_Rev2Session1/img25698.png is a low contrast image
#   return func(*args, **kwargs)
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/skimage/_shared/utils.py:328: UserWarning: /stelmo/nwb/deeplabcut/projects/Klein-Shijie_Gu-2025-10-03/labeled-data/20231101_klein_02_Rev2Session1/img31141.png is a low contrast image
#   return func(*args, **kwargs)
# Frames were successfully extracted, for the videos listed in the config.yaml file.
#
# You can now label the frames using the function 'label_frames' (Note, you should label frames extracted from diverse videos (and many videos; we do not recommend training on single videos!)).
# /home/shijiegu/anaconda3/envs/spyglass-dlc/lib/python3.10/site-packages/skimage/_shared/utils.py:328: UserWarning: /stelmo/nwb/deeplabcut/projects/Klein-Shijie_Gu-2025-10-03/labeled-data/20231101_klein_02_Rev2Session1/img02613.png is a low contrast image
#   return func(*args, **kwargs)
