# %%
import os
import datajoint as dj

from spyglass.common.common_usage import Export, ExportSelection
# Out:
# [2026-04-21 10:19:25,401][INFO]: DataJoint 0.14.4 connected to shijiegu-alt@lmf-db.cin.ucsf.edu:3306

# %% [markdown]
# ### 1. Behavior, EpochPos, Statescript, Change of mind table

# %%
from spyglass.shijiegu.Analysis_SGU import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from spyglass.shijiegu.Analysis_SGU import *
#
# File ~/Documents/spyglass/src/spyglass/shijiegu/Analysis_SGU.py:22
#      20 from spyglass.common import LFPBand
#      21 from spyglass.spikesorting.v0 import (SpikeSortingRecording)
# ---> 22 from spyglass.decoding.v0.clusterless import ClusterlessClassifierParameters
#      23 #from spyglass.utils import SpyglassMixin
#      24 from spyglass.spikesorting.v0.spikesorting_curation import Waveforms
#
# File ~/Documents/spyglass/src/spyglass/decoding/__init__.py:1
# ----> 1 from spyglass.decoding.decoding_merge import DecodingOutput  # noqa: E402
#       2 from spyglass.decoding.v1.clusterless import (  # noqa: E402
#       3     ClusterlessDecodingSelection,
#       4     ClusterlessDecodingV1,
#       5     UnitWaveformFeaturesGroup,
#       6 )
#       7 from spyglass.decoding.v1.core import (
#       8     DecodingParameters,
#       9     PositionGroup,
#      10 )  # noqa: E402
#
# File ~/Documents/spyglass/src/spyglass/decoding/decoding_merge.py:9
#       6 from non_local_detector.visualization.figurl_1D import create_1D_decode_view
#       7 from non_local_detector.visualization.figurl_2D import create_2D_decode_view
# ----> 9 from spyglass.decoding.v1.clusterless import ClusterlessDecodingV1  # noqa: F401
#      10 from spyglass.decoding.v1.sorted_spikes import (
#      11     SortedSpikesDecodingV1,
#      12 )  # noqa: F401
#      13 from spyglass.settings import config
#
# File ~/Documents/spyglass/src/spyglass/decoding/v1/clusterless.py:29
#      27 from spyglass.decoding.v1.core import PositionGroup
#      28 from spyglass.decoding.v1.utils import _get_interval_range
# ---> 29 from spyglass.decoding.v1.waveform_features import (
#      30     UnitWaveformFeatures,
#      31 )  # noqa: F401
#      32 from spyglass.position.position_merge import PositionOutput  # noqa: F401
#      33 from spyglass.settings import config
#
# File ~/Documents/spyglass/src/spyglass/decoding/v1/waveform_features.py:12
#      10 from spyglass.common.common_nwbfile import AnalysisNwbfile
#      11 from spyglass.settings import temp_dir
# ---> 12 from spyglass.spikesorting.spikesorting_merge import SpikeSortingOutput
#      13 from spyglass.spikesorting.v1 import SpikeSortingSelection
#      14 from spyglass.utils import SpyglassMixin
#
# File ~/Documents/spyglass/src/spyglass/spikesorting/spikesorting_merge.py:6
#       4 import numpy as np
#       5 from datajoint.utils import to_camel_case
# ----> 6 from ripple_detection import get_multiunit_population_firing_rate
#       8 from spyglass.spikesorting.imported import ImportedSpikeSorting  # noqa: F401
#       9 from spyglass.spikesorting.v0.spikesorting_curation import (
#      10     CuratedSpikeSorting,
#      11 )  # noqa: F401
#
# File ~/Documents/spyglass/src/spyglass/shijiegu/ripple_detection.py:17
#      12 from spyglass.common import (AnalysisNwbfile, IntervalList,interval_list_intersect, LFPBand, LFP, Electrode)
#      14 from spyglass.spikesorting.v0 import (SpikeSortingRecordingSelection,
#      15                                       ArtifactRemovedIntervalList)
# ---> 17 from ripple_detection.core import (gaussian_smooth,
#      18                                    get_envelope,
#      19                                    get_multiunit_population_firing_rate,
#      20                                    threshold_by_zscore,
#      21                                    merge_overlapping_ranges,
#      22                                    exclude_close_events,
#      23                                    extend_threshold_to_mean)
#      24 from itertools import chain
#      26 from ripple_detection.detectors import _get_event_stats
#
# ModuleNotFoundError: No module named 'ripple_detection.core'; 'ripple_detection' is not a package

# %%
ExportSelection().stop_export(**paper_key, analysis_id="change_of_mind_behavior")

# %%
from spyglass.shijiegu
